# %% [markdown]
# ## 상품정보가 포함된 하나의 페이지를 파싱하여 상품정보가 포함된 데이터 프레임을 생성

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# http://www.neweracapkorea.com/shop/shopbrand.html?xcode=031&mcode=002&type=Y&gf_ref=Yz1vU0FlS3M=
base_url = "http://www.neweracapkorea.com"
cap_total_url = "/shop/shopbrand.html?xcode=031&mcode=002&type=Y&gf_ref=Yz1vU0FlS3M="
base_url + cap_total_url
# Out:
# 'http://www.neweracapkorea.com/shop/shopbrand.html?xcode=031&mcode=002&type=Y&gf_ref=Yz1vU0FlS3M='

# %%
# get html
response = requests.get(base_url+cap_total_url)

# BeautifulSoup을 활용하여 데이터 파싱
soup = BeautifulSoup(response.content, "lxml")
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html>
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="CONTENT-TYPE"/>
# <link href="/shopimages/newerashop/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/shopimages/newerashop/mobile_web_icon.png" rel="apple-touch-icon-precomposed"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="website" property="og:type"/>
# <meta content="뉴에라 공식 온라인 스토어" property="og:title"/>
# <meta content="http://www.neweracapkorea.com/shopimages/newerashop/shopbrand_og_all_20220714162755phpGoLdgP.jpg" property="og:image"/>
# <link href="http://www.neweracapkorea.com/shopimages/newerashop/shopbrand_og_all_20220714162755phpGoLdgP.jpg" rel="image_src"/>
# <meta content="100년의 역사를 자랑하는 MLB 공식 파트너 뉴에라입니다." property="og:description"/>
# <meta content="http://www.neweracapkorea.com/shop/shopbrand.html?xcode=031&amp;mcode=002&amp;type=Y&amp;gf_ref=Yz1vU0FlS3M=" property="og:url"/>
# <title>MEN &gt; 모자</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="a3e4e840fe9e419b8e34b1064f4d0c9a46c54efd" name="naver-site-verification"/>
# <meta content="6Nl8EyimZc-dfQImXCJKEsojYPUxowwcTvw1kQufiG8" name="google-site-verification"/>
# <meta content="dhizokf3cqz9537jqyhy5kge71f3uz" name="facebook-domain-verification"/>
# <meta content="website" property="og:type"/>
# <meta content="뉴에라 공식 온라인 스토어" property="og:title"/>
# <meta content="MLB,NBA,NFL 미국 3대 스포츠 리그의 공식 선수용 모자 및 다양한 라이프 스타일 아이템" property="og:description"/>
# <meta content="//newera5950.jpg3.kr/img/202203brand.png" property="og:image"/>
# <meta content="//www.neweracapkorea.com" property="og:url"/>
# </head><body><span itemscope="" itemtype="//schema.org/Organization">
# <link href="//www.neweracapkorea.com" itemprop="url"/>
# <a href="https://twitter.com/NEWERA_KOREA" itemprop="sameAs"></a>
# <a href="https://www.instagram.com/newerakorea" itemprop="sameAs"></a>
# <a href="https://www.facebook.com/neweracapkorea" itemprop="sameAs"></a>
# <a href="https://blog.naver.com/neweraonline" itemprop="sameAs"></a>
# <a href="https://www.youtube.com/c/NewEraKorea1920/featured" itemprop="sameAs"></a>
# </span>
# <link href="/shopimages/newerashop/template/work/31124/common.css?r=1668753582" rel="stylesheet" type="text/css"/><link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:400,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,700" rel="stylesheet"/>
# <!-- Groobee Script -->
# <script type="text/javascript">
# (function(a,i,u,e,o) {
# a[u]=a[u]||function(){(a[u].q=a[u].q||[]).push(arguments)};
# })(window, document, "groobee");
# groobee("serviceKey", "2fbbbfb806274e70ac49e3b354d9fd8f");
# groobee("siteType", "makeshop");
# </script>
# <script charset="utf-8" src="//static.groobee.io/dist/lib/groobee.init.min.js"></script>
# <!-- End of Groobee Script -->
# <!-- Facebook Pixel Code 20220105 -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '939808506651161');
# fbq('track', 'PageView');
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=939808506651161&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code 20220105 -->
# <title>뉴에라 공식 온라인 스토어</title>
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
#     function setCookieCpa(cookie_name, cookie_value, expire_date) {
#         var cookieurl = '.neweracapkorea.com';
#         var today = new Date();
#         var expire = new Date();
#         expire.setTime(today.getTime() + 3600000 * 24 * expire_date);
#         cookies = cookie_name + '=' + cookie_value + '; path=/;';
#         cookies += (cookieurl) ? ' DOMAIN=' + cookieurl + '; ' : '';
#         if (expire_date != 0) cookies += 'expires=' + expire.toGMTString();
#         document.cookie = cookies;
#     }
#
#     if (typeof wcs == 'object') {   // typeof WCS start
#         if(!wcs_add) var wcs_add = {};
#         wcs_add["wa"] = "s_3c3da035b15";
#         wcs.checkoutWhitelist = ["neweracapkorea.com","www.neweracapkorea.com"];
#
#         // referrer
#         wcs.inflow("neweracapkorea.com");
#         if (wcs.isCPA) {
#             setCookieCpa('isCPA', 'Y', 1);
#         }
#
#     }   // typeof WCS END
#
# //-->
# </script>
# <script src="/js/jquery-1.7.2.min.js" type="text/javascript"></script>
# <script charset="UTF-8" src="/shopimages/newerashop/netfunnel.js?20221115" type="text/javascript"></script><script src="/js/lazyload.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# function getCookiefss(name) {
#     lims = document.cookie;
#     var index = lims.indexOf(name + "=");
#     if (index == -1) {
#         return null;
#     }
#     index = lims.indexOf("=", index) + 1; // first character
#     var endstr = lims.indexOf(';', index);
#     if (endstr == -1) {
#         endstr = lims.length; // last character
#     }
#     return unescape(lims.substring(index, endstr));
# }
# </script><script type="text/javascript">
# var MOBILE_USE = '';
# </script><script src="/js/flash.js" type="text/javascript"></script>
# <script src="/js/neodesign/rightbanner.js" type="text/javascript"></script>
# <script src="/js/bookmark.js" type="text/javascript"></script>
# <style type="text/css">
#
# .MS_search_word { }
#
# </style>
# <script src="/js/jquery.shopbrand.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# var pre_ORBAS = 'A';
# var pre_min_amount = '1';
# var pre_product_uid = '';
# var pre_product_name = '';
# var pre_product_price = '';
# var pre_option_type = '';
# var pre_option_display_type = '';
# var pre_optionJsonData = '';
# var IS_LOGIN = 'false';
# var is_bulk = 'N';
# var bulk_arr_info = [];
# var pre_min_add_amount = '1';
# var pre_max_amount = '100000';
#
#     var is_unify_opt = '1' ? true : false;
#     var pre_baskethidden = 'A';
#
# var is_unify_opt = true;
# var ORBAS = 'A';
# var min_amount = '1';
# var min_add_amount = '1';
# var max_amount = '100000';
# var product_uid = '';
# var product_name = '';
# var product_price = '';
# var option_type = '';
# var option_display_type = '';
# var is_dummy = null;
# var is_exist = null;
# var optionJsonData = '';
# var view_member_only_price = '';
# var IS_LOGIN = 'false';
# var shop_language = 'kor';
# var is_bulk = 'N';
# var bulk_arr_info = [];
#
# </script>
# <link href="/shopimages/newerashop/template/work/31124/shopbrand.cate2.css?t=202208191111" rel="stylesheet" type="text/css"/>
# <div id="blk_scroll_wings"><script src="/html/shopRbanner.html?param1=1" type="text/javascript"></script></div>
# <div id="cherrypicker_scroll"></div>
# <div id="wrap">
# <link href="/shopimages/newerashop/template/work/31124/header.1.css?t=202301270747" rel="stylesheet" type="text/css"/>
# <!-- Groobee Basic Data -->
# <meta content="" property="groobee:member_id"/>
# <meta content="" property="groobee:member_grade"/>
# <!-- End of Groobee Basic Data -->
# <!-- Channel Plugin Scripts -->
# <script>
#   function parsePureNumber(number) {
#     return parseFloat(number.replace(/[^0-9\.]+/g, '')) || 0
#   }
#   var settings = {
#     "pluginKey": "7d2b071a-63fa-42e6-9a1a-f8a532e663cb",
#   };
#       (function() {
#     var w = window;
#     if (w.ChannelIO) {
#       return (window.console.error || window.console.log || function(){})('ChannelIO script included twice.');
#     }
#     var ch = function() {
#       ch.c(arguments);
#     };
#     ch.q = [];
#     ch.c = function(args) {
#       ch.q.push(args);
#     };
#     w.ChannelIO = ch;
#     function l() {
#       if (w.ChannelIOInitialized) {
#         return;
#       }
#       w.ChannelIOInitialized = true;
#       var s = document.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.src = 'https://cdn.channel.io/plugin/ch-plugin-web.js';
#       s.charset = 'UTF-8';
#       var x = document.getElementsByTagName('script')[0];
#       x.parentNode.insertBefore(s, x);
#     }
#     if (document.readyState === 'complete') {
#       l();
#     } else if (window.attachEvent) {
#       window.attachEvent('onload', l);
#     } else {
#       window.addEventListener('DOMContentLoaded', l, false);
#       window.addEventListener('load', l, false);
#     }
#   })();
#   if (settings && settings.memberId && settings.memberId.indexOf('!--/user_id/--') >= 0) {
#     console.error('You do not using makeshop. please visit https://developers.channel.io/docs/guide-for-famous-builders and find correct one');
#   } else {
#     ChannelIO('boot', settings);
#   }
# </script>
# <!-- End Channel Plugin -->
# <script src="/design/newerashop/0751decode/js/jquery.easing.1.3.min.js" type="text/javascript"></script>
# <script src="/design/newerashop/0751decode/js/jquery.sliderkit.1.9.2.pack.js" type="text/javascript"></script>
# <div id="mheader">
# <div style="height:1px; background-color:#000;"></div>
# <div id="comment_top">
# <!-- 상단 텍스트 배너 -->
# <div class="top_text_ban">
# <div class="sliderkit contentslider-text">
# <div class="text_arrow">
# <div class="sliderkit-go-btn sliderkit-go-prev"><a href="#none" title="Previous"><span>[↑]</span></a></div>
# <div class="sliderkit-go-btn sliderkit-go-next"><a href="#none" title="Next"><span>[↓]</span></a></div>
# </div>
# <!-- 회원인 경우 -->
# <div class="sliderkit-panels">
# <div class="sliderkit-panel"><a href="/shop/page.html?id=207">회원가입 시 웰컴 1만원, 2만원 5만원 할인쿠폰 즉시 발급!</a></div>
# <!--<div class="sliderkit-panel"><a href="/shop/page.html?id=93&gf_ref=Yz02bFBHTmM=">회원 가입 시 무료배송/반품/교환(1회)</a></div>-->
# </div>
# <!-- 나의 적립금 -->
# </div>
# </div>
# <!-- 상단 영역01 -->
# <div class="header_sec01 cboth">
# <div class="fright top_log_area">
# <ul>
# <li><a href="/shop/member.html?type=login">로그인</a></li>
# <li><a href="/shop/idinfo.html">회원가입</a></li>
# <li><a href="/shop/basket.html">장바구니</a></li>
# <li><a href="/shop/member.html?type=mynewmain">마이페이지</a></li>
# <li><a class="top_wish" href="/shop/page.html?id=2">매장안내</a></li>
# </ul>
# </div>
# </div>
# <!-- 상단 영역02 -->
# <div class="header_sec02 cboth">
# <div class="inner">
# <div>
# <!-- 상단 로고 -->
# <div class="top_logo"><a href="/index.html"><img src="//newera5950.jpg3.kr/img/top_logo_w.jpg"/></a></div>
# <!-- 상단 검색 시작 -->
# <div class="search_top">
# <div class="search_form">
# <form action="/shop/shopbrand.html" method="post" name="search"> <fieldset><legend>검색 폼</legend>
# <div class="cboth search_box"><input class="MS_search_word search_auto_completion" name="search" onkeydown="CheckKey_search();" value=""/> <a href="javascript:search_submit();"><input class="search_btn" src="/design/newerashop/0751decode/btn_search.gif" type="image"/></a></div>
# </fieldset>
# </form></div>
# <div class="search-auto-complete-list"></div>
# <!-- 검색창 삽입 문구 수정 -->
# <script type="text/javascript"> document.search.search.value  = '팔로(FFALO)'; </script>
# <script type="text/javascript">
# 			document.search.search.onfocus = function () { this.value = ''; } </script>
# <!-- 인기검색어 -->
# <div class="search_pop">
# <div class="search_pop_title">인기 검색어</div>
# <div class="search_pop_list">
# <!-- 인기검색어 입력 및 링크 수정 -->
# <a href="/shop/shopbrand.html?search=&amp;prize1=팔로"><span>1</span>팔로</a>
# <a href="/shop/shopbrand.html?search=&amp;prize1=구스다운"><span>2</span>구스다운</a>
# <a href="/shop/shopbrand.html?search=&amp;prize1=핀치히터"><span>3</span>핀치히터</a>
# <a href="/shop/shopbrand.html?xcode=114&amp;mcode=001&amp;scode=027&amp;type=Y"><span>4</span>블랙라벨</a>
# <a href="/shop/shopbrand.html?search=&amp;prize1=코듀로이 모자"><span>5</span>코듀로이 모자</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=005"><span>6</span>비니</a>
# <a href="/shop/shopbrand.html?xcode=028&amp;type=P"><span>7</span>신상</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;type=Y"><span>8</span>골프</a>
# <a href="/shop/shopbrand.html?search=&amp;prize1=쿠퍼스타운"><span>9</span>쿠퍼스타운</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=004&amp;scode=008&amp;type=Y"><span>10</span>팬츠</a>
# </div>
# </div>
# </div>
# </div>
# <!-- 상단 카테고리 시작 -->
# <div class="top_cate">
# <ul>
# <!-- 상단  MEN 전체 카테고리 -->
# <li class="section2" onmouseout="javascript:setmenutimer();" onmouseover="javascript:showmenu('submenu1');"><a href="/shop/shopbrand.html?xcode=031&amp;type=Y"><span>MEN</span></a>
# <div class="top_all_cate" id="submenu1" onmouseout="javascript:setmenutimer();" onmouseover="javascript:resetmenutimer();">
# <div class="inner">
# <div class="cate_area01 fleft">
# <a href="/shop/shopbrand.html?xcode=116&amp;mcode=001&amp;type=Y">MEMBER SHOP</a>
# <a href="/shop/shopbrand.html?xcode=108&amp;type=Y">한화 이글스</a>
# <a href="/shop/shopbrand.html?xcode=028&amp;type=P">신상품</a>
# <a href="/shop/shopbrand.html?xcode=058&amp;type=P&amp;gf_ref=Yz1sWEdPWHc=">인기상품</a>
# <a href="/shop/page.html?id=214">2023 컬렉션</a>
# <a href="/shop/page.html?id=177">콜라보레이션</a>
# <a href="/shop/shopbrand.html?xcode=045&amp;type=Y&amp;gf_ref=Yz11RzNza24=">59FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=046&amp;type=Y&amp;gf_ref=Yz1lNmpkN3Q=">9FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=048&amp;type=Y&amp;gf_ref=Yz1XY1RLRW4=">9FORTY</a>
# <a href="/shop/shopbrand.html?xcode=047&amp;type=P&amp;gf_ref=Yz00UDg1WXI=">39THIRTY</a>
# <a href="//neweracapkorea.com/shop/page.html?id=139&amp;gf_ref=Yz1jRU5sVkc=">#THISISMYNEWRA</a>
# </div>
# <div class="cate_area02 fleft">
# <p>모자</p>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=002&amp;type=Y&amp;gf_ref=Yz1vU0FlS3M=">모자 전체</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=001&amp;gf_ref=Yz1tSVpwTkE=">볼캡</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=002&amp;scode=007&amp;type=Y&amp;gf_ref=Yz02V3l0T3E=">K프레임 볼캡</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=002&amp;gf_ref=Yz00OW5MYjE=">일자챙</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=010">버킷 햇</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=003&amp;gf_ref=Yz1zSzNueVk=">제트캡 (캠퍼)</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=008&amp;gf_ref=Yz1pTnVYOWY=">시즈널캡</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=005&amp;gf_ref=Yz02dktwdW4=">비니</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=002&amp;scode=006&amp;gf_ref=Yz1JbkdLR1M=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>의류</p>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=004&amp;type=Y&amp;gf_ref=Yz1SMGxLd00=">의류 전체</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=004&amp;scode=002&amp;type=Y&amp;gf_ref=Yz1ReFR4eVA=">아우터</a>
# <a href="/shop/shopbrand.html?xcode=054&amp;mcode=011&amp;type=Y">후드 Ι 맨투맨</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=004&amp;scode=008&amp;type=Y&amp;gf_ref=Yz1oUnRndWQ=">팬츠</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=004&amp;scode=005&amp;type=Y&amp;gf_ref=Yz1SZ042VlY=">티셔츠</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=004&amp;scode=009&amp;type=Y">언더웨어</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=004&amp;scode=007&amp;type=Y&amp;gf_ref=Yz1sUmxscXE=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>액세서리</p>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=005&amp;type=Y&amp;gf_ref=Yz1oNVpqQlA=">액세서리 전체</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=005&amp;scode=001&amp;type=Y&amp;gf_ref=Yz15TG44VkM=">백팩</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=005&amp;scode=003&amp;type=Y&amp;gf_ref=Yz00MWYwWnE=">기타 가방</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=005&amp;scode=004&amp;type=Y&amp;gf_ref=Yz1DV2RLeXA=">캡 관련 용품</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=005&amp;scode=007">양말</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=005&amp;scode=005&amp;type=Y&amp;gf_ref=Yz1wQmN2SHM=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>스포츠</p>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=001&amp;type=Y&amp;gf_ref=Yz1VbkNiTmI=">스포츠 전체</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=001&amp;scode=001&amp;type=Y&amp;gf_ref=Yz1UQlByMHU=">MLB 공식 선수용</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=001&amp;scode=002&amp;type=Y&amp;gf_ref=Yz1nM2ZSRkQ=">MLB LIFE STYLE</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=001&amp;scode=003&amp;type=Y&amp;gf_ref=Yz1WVHN0UXU=">NBA</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=001&amp;scode=004&amp;type=Y&amp;gf_ref=Yz1SY296VUE=">NFL</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=001&amp;scode=008&amp;type=Y&amp;gf_ref=Yz1UMXVQeXA=">FOOTBALL</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;mcode=001&amp;scode=007&amp;type=Y&amp;gf_ref=Yz1iU1BDMUU=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>온라인 온리</p>
# <a href="/shop/shopbrand.html?xcode=087&amp;type=Y&amp;gf_ref=Yz1tUWdiWGM=">온라인 온리 전체</a>
# <a href="/shop/shopbrand.html?xcode=087&amp;mcode=005&amp;type=Y&amp;gf_ref=Yz1rV1pERUY=">온라인 온리 스타일</a>
# <a href="/shop/shopbrand.html?xcode=087&amp;mcode=006&amp;type=Y&amp;gf_ref=Yz1xcHJtWUQ=">온라인 온리 사이즈</a>
# </div>
# </div>
# </div>
# </li>
# <!-- 상단 WOMEN 전체 카테고리 -->
# <li onmouseout="javascript:setmenutimer();" onmouseover="javascript:showmenu('submenu2');"><a href="/shop/shopbrand.html?xcode=019&amp;type=Y"><span>WOMEN</span></a>
# <div class="top_all_cate" id="submenu2" onmouseout="javascript:setmenutimer();" onmouseover="javascript:resetmenutimer();">
# <div class="inner">
# <div class="cate_area01 fleft">
# <a href="/shop/shopbrand.html?xcode=116&amp;mcode=001&amp;type=Y">MEMBER SHOP</a>
# <a href="/shop/shopbrand.html?xcode=108&amp;type=Y">한화 이글스</a>
# <a href="/shop/shopbrand.html?xcode=028&amp;type=P">신상품</a>
# <a href="/shop/shopbrand.html?xcode=058&amp;type=P&amp;gf_ref=Yz1sWEdPWHc=">인기상품</a>
# <a href="/shop/page.html?id=214">2023 컬렉션</a>
# <a href="/shop/page.html?id=177">콜라보레이션</a>
# <a href="/shop/shopbrand.html?xcode=045&amp;type=Y&amp;gf_ref=Yz11RzNza24=">59FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=046&amp;type=Y&amp;gf_ref=Yz1lNmpkN3Q=">9FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=048&amp;type=Y&amp;gf_ref=Yz1XY1RLRW4=">9FORTY</a>
# <a href="/shop/shopbrand.html?xcode=047&amp;type=P&amp;gf_ref=Yz00UDg1WXI=">39THIRTY</a>
# <a href="//neweracapkorea.com/shop/page.html?id=139&amp;gf_ref=Yz1jRU5sVkc=">#THISISMYNEWRA</a>
# </div>
# <div class="cate_area02 fleft">
# <p>모자</p>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=003&amp;type=Y&amp;gf_ref=Yz1lVkN0VWs=">모자 전체</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=003&amp;scode=001&amp;gf_ref=Yz1vVUoycWM=">볼캡</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=003&amp;scode=007&amp;gf_ref=Yz1wcWpRZmg=">K프레임 볼캡</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=003&amp;scode=002&amp;gf_ref=Yz1uUFQyVGs=">일자챙</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=003&amp;scode=009&amp;type=Y">버킷 햇</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=003&amp;scode=003&amp;gf_ref=Yz1KV0JCU00=">제트캡 (캠퍼)</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=003&amp;scode=008&amp;gf_ref=Yz1EZjQxTzI=">시즈널캡</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=003&amp;scode=005&amp;gf_ref=Yz1DS2xmU1M=">비니</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=003&amp;scode=006&amp;gf_ref=Yz1pTzVNcDY=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>의류</p>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=005&amp;type=Y&amp;gf_ref=Yz1wNjRzZmE=">의류 전체</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=005&amp;scode=002&amp;type=Y&amp;gf_ref=Yz1MYWw4QkM=">아우터</a>
# <a href="/shop/shopbrand.html?xcode=054&amp;mcode=011&amp;type=Y">후드 Ι 맨투맨</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=005&amp;scode=008&amp;gf_ref=Yz0zcEh2Z1A=">팬츠</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=005&amp;scode=005&amp;gf_ref=Yz1hUkxLbUg=">티셔츠</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=005&amp;scode=007&amp;gf_ref=Yz1hV0ZCRk8=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>액세서리</p>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=006&amp;type=Y&amp;gf_ref=Yz0zcUdSY1Q=">액세서리 전체</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=006&amp;scode=001&amp;type=Y&amp;gf_ref=Yz1JOGJ1WlY=">백팩</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=006&amp;scode=003&amp;type=Y&amp;gf_ref=Yz05NTc4YzE=">기타 가방</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=006&amp;scode=004&amp;type=Y&amp;gf_ref=Yz1MQlY1WEc=">캡 관련 용품</a>
# <a href="/shop/shopbrand.html?xcode=031&amp;type=N&amp;mcode=005&amp;scode=007">양말</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=006&amp;scode=005&amp;type=Y&amp;gf_ref=Yz1vYjFES2w=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>스포츠</p>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=002&amp;type=Y&amp;gf_ref=Yz11MjI2dlc=">스포츠 전체</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;type=N&amp;mcode=002&amp;scode=001&amp;gf_ref=Yz0yd2V0OWE=">MLB 공식 선수용</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=002&amp;scode=002&amp;type=Y&amp;gf_ref=Yz1uV2p5aHc=">MLB LIFE STYLE</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=002&amp;scode=003&amp;type=Y&amp;gf_ref=Yz1PYXdMNEg=">NBA</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=002&amp;scode=004&amp;type=Y&amp;gf_ref=Yz0wWkNFMjQ=">NFL</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=002&amp;scode=008&amp;type=Y&amp;gf_ref=Yz1kSENwN3Y=">FOOTBALL</a>
# <a href="/shop/shopbrand.html?xcode=019&amp;mcode=002&amp;scode=007&amp;type=Y">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>온라인 온리</p>
# <a href="/shop/shopbrand.html?xcode=087&amp;type=Y&amp;gf_ref=Yz1tUWdiWGM=">온라인 온리 전체</a>
# <a href="/shop/shopbrand.html?xcode=087&amp;mcode=005&amp;type=Y&amp;gf_ref=Yz1rV1pERUY=">온라인 온리 스타일</a>
# <a href="/shop/shopbrand.html?xcode=087&amp;mcode=006&amp;type=Y&amp;gf_ref=Yz1xcHJtWUQ=">온라인 온리 사이즈</a>
# </div>
# </div>
# </div>
# </li>
# <!-- 상단 KIDS  전체 카테고리 시작-->
# <li class="kids" onmouseout="javascript:setmenutimer();" onmouseover="javascript:showmenu('submenu3');"><a href="/shop/shopbrand.html?xcode=080&amp;type=Y&amp;gf_ref=Yz1vd1ByTEQ="><span>KIDS </span></a>
# <div class="top_all_cate" id="submenu3" onmouseout="javascript:setmenutimer();" onmouseover="javascript:resetmenutimer();">
# <div class="inner">
# <div class="cate_area01 fleft">
# <a href="/shop/shopbrand.html?xcode=116&amp;mcode=001&amp;type=Y">MEMBER SHOP</a>
# <a href="/shop/shopbrand.html?xcode=108&amp;type=Y">한화 이글스</a>
# <a href="/shop/shopbrand.html?xcode=091&amp;type=P">신상품</a>
# <a href="/shop/shopbrand.html?xcode=040&amp;type=P">인기상품</a>
# <a href="/shop/page.html?id=176">22/23 키즈 컬렉션</a>
# <a href="/shop/shopbrand.html?xcode=045&amp;type=Y">59FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=046&amp;type=Y">9FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=048&amp;type=Y">9FORTY</a>
# <a href="/shop/shopbrand.html?xcode=047&amp;type=P">39THIRTY</a>
# <a href="//neweracapkorea.com/shop/page.html?id=139&amp;gf_ref=Yz1jRU5sVkc=">#THISISMYNEWRA</a>
# </div>
# <div class="cate_area02 fleft">
# <p>모자</p>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;type=Y">모자 전체</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=007&amp;scode=001&amp;type=Y">마이퍼스트(0-2세)</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;scode=001&amp;type=Y">볼캡</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;scode=007&amp;type=Y&amp;gf_ref=Yz04cFppTDY=">K프레임 볼캡</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;scode=002&amp;type=Y">일자챙</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;scode=003&amp;type=Y">제트캡(캠퍼)</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;scode=008&amp;type=Y">시즈널캡</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;scode=005&amp;type=Y">비니</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=001&amp;scode=006&amp;type=Y">기타</a>
# </div>
# <!--<div class="cate_area02 fleft">
# 	  <p>사이즈별</p>
# 	  <a href="/shop/shopbrand.html?xcode=025&mcode=007&scode=001&type=Y">마이퍼스트(0-2세)</a>
# 	  <a href="/shop/shopbrand.html?xcode=025&type=N&mcode=005&scode=002">토들러(2-4세)</a>
# 	  <a href="/shop/shopbrand.html?xcode=025&type=N&mcode=005&scode=003">차일드(4-6세)</a>
# 	  <a href="/shop/shopbrand.html?xcode=025&type=N&mcode=005&scode=004">유스(6-12세)</a>
# 	  </div>-->
# <div class="cate_area02 fleft">
# <p>의류</p>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=002&amp;type=Y">의류 전체</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=002&amp;scode=002&amp;type=Y">아우터</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=002&amp;scode=010&amp;type=Y">후드 Ι 맨투맨</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=002&amp;scode=006&amp;type=Y">팬츠</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=002&amp;scode=005&amp;type=Y">티셔츠</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=002&amp;scode=007&amp;type=Y">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>액세서리</p>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=003&amp;type=Y">액세서리 전체</a>
# <a href="/shop/shopbrand.html?xcode=094&amp;mcode=001&amp;scode=001&amp;type=Y">키즈 가방</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=003&amp;scode=004&amp;type=Y">캡 관련 용품</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=003&amp;scode=005&amp;type=Y">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>키즈 스포츠</p>
# <a href="/shop/shopbrand.html?search=&amp;prize1=키즈 어센틱">MLB 공식 선수용</a>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=004&amp;scode=007&amp;type=Y">MLB 라이프스타일</a>
# <a href="/shop/shopbrand.html?search=&amp;prize1=키즈 NFL">NFL</a>
# <a href="/shop/shopbrand.html?search=&amp;prize1=키즈 피싱">FISHING</a>
# </div>
# <div class="cate_area02 fleft">
# <p>키즈 온라인 온리</p>
# <a href="/shop/shopbrand.html?xcode=025&amp;mcode=006&amp;scode=001&amp;type=Y">온라인 온리 스타일</a>
# </div>
# </div>
# </div>
# </li>
# <!-- 상단 GOLF  전체 카테고리 시작 -->
# <li onmouseout="javascript:setmenutimer();" onmouseover="javascript:showmenu('submenu4');"><a href="/shop/shopbrand.html?xcode=076&amp;type=P&amp;gf_ref=Yz1ybTRWUkk="><span> GOLF</span></a>
# <div class="top_all_cate" id="submenu4" onmouseout="javascript:setmenutimer();" onmouseover="javascript:resetmenutimer();">
# <div class="inner">
# <div class="cate_area01 fleft">
# <a href="/shop/shopbrand.html?xcode=116&amp;mcode=001&amp;type=Y">MEMBER SHOP</a>
# <a href="/shop/shopbrand.html?xcode=108&amp;type=Y">한화 이글스</a>
# <a href="/shop/shopbrand.html?xcode=028&amp;type=P">신상품</a>
# <a href="/shop/shopbrand.html?xcode=058&amp;type=P&amp;gf_ref=Yz1sWEdPWHc=">인기상품</a>
# <a href="/shop/page.html?id=175">2023 컬렉션</a>
# <a href="/shop/page.html?id=177"> 콜라보레이션</a>
# <a href="/shop/shopbrand.html?xcode=045&amp;type=Y&amp;gf_ref=Yz11RzNza24=">59FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=046&amp;type=Y&amp;gf_ref=Yz1lNmpkN3Q=">9FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=048&amp;type=Y&amp;gf_ref=Yz1XY1RLRW4=">9FORTY</a>
# <a href="/shop/shopbrand.html?xcode=047&amp;type=P&amp;gf_ref=Yz00UDg1WXI=">39THIRTY</a>
# <a href="//neweracapkorea.com/shop/page.html?id=139&amp;gf_ref=Yz1jRU5sVkc=">#THISISMYNEWRA</a>
# </div>
# <div class="cate_area02 fleft">
# <p>골프 모자</p>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=001&amp;type=Y&amp;gf_ref=Yz1JNjF4eEs=">모자 전체</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=001&amp;scode=001&amp;type=Y&amp;gf_ref=Yz16T1h4QWo=">볼캡</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=001&amp;scode=002&amp;type=Y&amp;gf_ref=Yz02VXdITHk=">A프레임 볼캡</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=001&amp;scode=004&amp;type=Y">일자챙</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=001&amp;scode=003&amp;type=Y&amp;gf_ref=Yz1HNXU3TTM=">기타</a>
# </div>
# <div class="cate_area02 fleft">
# <p>골프 의류</p>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=002&amp;type=Y&amp;gf_ref=Yz1qTkNHSjc=">의류 전체</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=002&amp;scode=001&amp;type=Y&amp;gf_ref=Yz1DMUppQlM=">상의</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=002&amp;scode=002&amp;type=Y&amp;gf_ref=Yz1vdXBnaFE=">하의</a>
# </div>
# <div class="cate_area02 fleft">
# <p>골프 액세서리</p>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=003&amp;type=Y&amp;gf_ref=Yz0yUXYyRlY=">액세서리 전체</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=003&amp;scode=001&amp;type=Y&amp;gf_ref=Yz1tQk1FWlU=">가방</a>
# <a href="/shop/shopbrand.html?xcode=088&amp;mcode=003&amp;scode=002&amp;type=Y&amp;gf_ref=Yz1HWndYNkY=">기타</a>
# </div>
# </div>
# </div>
# </li>
# <!-- 상단 블랙라벨  전체 카테고리 시작 -->
# <li onmouseout="javascript:setmenutimer();" onmouseover="javascript:showmenu('submenu5');"><a href="/shop/shopbrand.html?xcode=081&amp;type=Y"><span>BLACK LABEL</span></a>
# <div class="top_all_cate" id="submenu5" onmouseout="javascript:setmenutimer();" onmouseover="javascript:resetmenutimer();">
# <div class="inner">
# <div class="cate_area01 fleft">
# <a href="/shop/shopbrand.html?xcode=116&amp;mcode=001&amp;type=Y">MEMBER SHOP</a>
# <a href="/shop/shopbrand.html?xcode=108&amp;type=Y">한화 이글스</a>
# <a href="/shop/shopbrand.html?xcode=028&amp;type=P">신상품</a>
# <a href="/shop/shopbrand.html?xcode=058&amp;type=P&amp;gf_ref=Yz1sWEdPWHc=">인기상품</a>
# <a href="/shop/page.html?id=175">2023 컬렉션</a>
# <a href="/shop/page.html?id=177"> 콜라보레이션</a>
# <a href="/shop/shopbrand.html?xcode=045&amp;type=Y&amp;gf_ref=Yz11RzNza24=">59FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=046&amp;type=Y&amp;gf_ref=Yz1lNmpkN3Q=">9FIFTY</a>
# <a href="/shop/shopbrand.html?xcode=048&amp;type=Y&amp;gf_ref=Yz1XY1RLRW4=">9FORTY</a>
# <a href="/shop/shopbrand.html?xcode=047&amp;type=P&amp;gf_ref=Yz00UDg1WXI=">39THIRTY</a>
# <a href="//neweracapkorea.com/shop/page.html?id=139&amp;gf_ref=Yz1jRU5sVkc=">#THISISMYNEWRA</a>
# </div>
# <div class="cate_area02 fleft">
# <p>BLACK LABEL</p>
# <a href="/shop/shopbrand.html?xcode=081&amp;type=P">블랙라벨 전체</a>
# <a href="/shop/shopbrand.html?xcode=082&amp;mcode=001&amp;type=Y">모자</a>
# <a href="/shop/shopbrand.html?xcode=082&amp;mcode=002&amp;type=Y">상의</a>
# <a href="/shop/shopbrand.html?xcode=082&amp;mcode=003&amp;type=Y">하의</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <!-- 상단 카테고리 끝 -->
# </div>
# </div>
# </div>
# </div>
# <script src="/shopimages/newerashop/template/work/31124/header.1.js?t=202301270747" type="text/javascript"></script>
# <div id="contentWrapper">
# <div id="contentWrap">
# <link href="/shopimages/newerashop/template/work/31124/menu.1.css?t=202107021516" rel="stylesheet" type="text/css"/>
# <div id="content">
# <div id="productClass">
# <style>
# #mheader {margin-bottom:5px !important;}
# </style>
# <!--전체 중분류-->
# <!-- 카카오픽셀 -->
# <script charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script>
# <script type="text/javascript">
#       kakaoPixel('7231124862609608075').pageView('PC방문');
# </script>
# <div class="width1200">
# <div class="sub_top_ban cboth">
# <!--PC가이드-->
# <style>
#
#      .title {
#          margin-top: 30px;
#
#          text-align: center;
#          font-size: 35px;
#          font-weight: 700;
#          color: #000;
#          letter-spacing: 0px;
#          line-height: 1.5;
#
#          /*제목 영어*/
#          /*font-family: 'Roboto Condensed', sans-serif;*/
#
#           /*제목 한국어*/
#          font-family: 'Noto Sans KR',sans-serif;
#      }
#
#      .title01 {
#          text-align: center;
#
#          font-size: 16px;
#          font-weight: 300;
#          color: #000;
#          letter-spacing: -0.5px;
#          line-height: 1.6;
#
#      }
#
#
#     .mtext_vip {
#         margin-top: 8px;
#
#         font-size: 13px;
#         font-weight: 400;
#         color: #3c3c3c;
#         letter-spacing: -0.5px;
#         line-height: 1.6;
#         text-align: center;
#     }
#
#     .title02 {
#          margin-top:20px;
#
#          text-align: center;
#          font-size: 16px;
#          font-weight: 300;
#          color: #000;
#          letter-spacing: -0.5px;
#          line-height: 1.6;
#
#
#      }
#
#
# </style>
# <!--<div class="title022">59FIFTY / 9FIFTY / 9FIFTY STRETCH / 9FORTY / 9FORTY UNST / 9FORTY KF / 39THIRTY / 9TWENT / 9TWENTY UNST / CSL </div>-->
# <!--메인 이미지-->
# <div>
# <iframe allowfullscreen="true" alt="The 22 Step" frameborder="0" height="574" src="https://www.youtube.com/embed/tcUcB03jYaw?autoplay=1" width="1200">
# </iframe>
# </div>
# <!--제목-->
# <div class="title">모자</div>
# <!--설명-->
# <div class="title01">1920년부터 시작된 모자에 대한 뉴에라의 노력은 멈추지 않습니다.
#  <br/>100년의 노하우와 기술력으로 탄생한 뉴에라의 다양한 실루엣별 제품들을 만나보세요.</div>
# <!--TIP설명-->
# <!--<div class="mtext_vip"><b>TIP.</b> 다양한 볼캡 실루엣은 실루에 가이드를 참고해 주세요. 제품 리스트에서 영문 제품명의 앞부분을 확인하시면 실루엣을 간단히 확인할 수 있습니다.<br>(ex. 940 = 9FORTY, 940UNST = 9FORTY의 언스트럭쳐캡) </div>-->
# <!--링크걸기-->
# <div class="title02">
# <a href="http://neweracapkorea.com/shop/page.html?id=32">
# <b><u>모자별 실루엣 가이드 보러가기</u></b>
# </a>
# </div>
# <!--//분류상단::코드HTML::끝//-->
# </div>
# <!-- 추가 배너 -->
# <div class="sub_top_ban cboth none"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/sub_ban_men.jpg"/></div>
# <div class="width1200" style="padding-top:20px;">
# <!--<div class="prd-class-hd">
# 		<dl class="loc-navi">
# 			<dt class="blind">현재 위치</dt>
# 			   <dd>
# 				<a href="/">home</a>
# 				 &gt; <a href="/shop/shopbrand.html?xcode=031&type=Y">MEN</a>				<!-- &gt; <a href="/shop/shopbrand.html?xcode=031&type=N&mcode=002">모자</a>				<!--			<!--</dd>
# 		</dl>
# 	</div>-->
# <!-- .prd-class-hd -->
# <!--<h2 class="bcate cboth">모자<!--</h2>-->
# </div>
# <div class="page-body">
# <h3 class="blind">상품 정보, 정렬</h3>
# <div class="cboth total-sort">
# <div class="width1200">
# <dl class="total"><dd style="color:#000;">897</dd> PRODUCT IN THIS CATEGORY</dl>
# <dl class="sort">
# <dt class="blind">검색결과 정렬</dt>
# <dd>
# <ul>
# <li><a class="sort_on" href="javascript:sendsort('sellcnt')">인기순</a></li>
# <li><a href="javascript:sendsort('regdate')">신상품순</a></li>
# <li><a href="javascript:sendsort('brandname')">이름순</a></li>
# <li><a href="javascript:sendsort('price')">낮은 가격순</a></li>
# <li><a href="javascript:sendsort('price2')">높은 가격순</a></li>
# <li><a href="javascript:sendsort('viewcnt')">상품 리뷰순</a></li>
# </ul>
# </dd>
# </dl>
# </div>
# </div><!-- .total-sort -->
# <div class="width1200">
# <div class="prd-list pdt30">
# <table summary="상품이미지, 상품 설명, 가격">
# <caption>상품 리스트</caption>
# <colgroup>
# <col width="20%"/>
# <col width="20%"/>
# <col width="20%"/>
# <col width="20%"/>
# <col width="20%"/>
# </colgroup>
# <tbody>
# <tr class="nopadding"><td></td><td></td><td></td><td></td><td></td></tr>
# <tr>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=4633&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bmp%2BW1w%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0610010002407.jpg?1577324526" src="/shopimages/newerashop/0610010002403.jpg?1562321305"/></a>
# </div>
# <ul class="info">
# <li class="dsc">MLB 팀 클래식 뉴욕 양키스 게임 볼..</li>
# <li class="product_etc">TEAM CLASSIC 3930 NEYYAN GM</li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('4633',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('061001000240', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3353027&amp;xcode=031&amp;mcode=002&amp;scode=002&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bm11W10%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0030010014417.jpg?1639378231" src="/shopimages/newerashop/0030010014413.jpg?1639378231"/></a>
# </div>
# <ul class="info">
# <li class="dsc">에센셜 무지 사이즈캡 블랙</li>
# <li class="product_etc">5950 ESSENTIAL BLK</li> <li class="pdt10"></li>
# <li class="price">49,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('3353027',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('003001001441', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"><img class="MK-product-icon-2" src="/shopimages/newerashop/prod_icons/27991?1640309123"/></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3353022&amp;xcode=031&amp;mcode=002&amp;scode=007&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bmp0W14%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0600040001617.jpg?1639378133" src="/shopimages/newerashop/0600040001613.jpg?1639378133"/></a>
# </div>
# <ul class="info">
# <li class="dsc">에센셜 무지 K프레임 볼캡 블랙</li>
# <li class="product_etc">940KF ESSENTIAL BLK</li> <li class="pdt10"></li>
# <li class="price">39,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('3353022',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('060004000161', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"><img class="MK-product-icon-2" src="/shopimages/newerashop/prod_icons/27991?1640309123"/></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=4631&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bm18W18%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0610010002387.jpg?1577324820" src="/shopimages/newerashop/0610010002383.jpg?1539845334"/></a>
# </div>
# <ul class="info">
# <li class="dsc">MLB 팀 클래식 LA다저스 게임 볼캡..</li>
# <li class="product_etc">TEAM CLASSIC 3930 LOSDOD GM</li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('4631',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('061001000238', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=5687&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bmt6W1g%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0610010002437.jpg?1627005618" src="/shopimages/newerashop/0610010002433.jpg?1627005618"/></a>
# </div>
# <ul class="info">
# <li class="dsc">MLB 팀 클래식 보스턴 레드삭스 게임..</li>
# <li class="product_etc">TEAM CLASSIC 3930 BOSRED GM</li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('5687',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('061001000243', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=4218&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bG53VA%3D%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0610010002487.jpg?1577324941" src="/shopimages/newerashop/0610010002483.jpg?1562321348"/></a>
# </div>
# <ul class="info">
# <li class="dsc">MLB 팀 클래식 시카고 화이트 삭스..</li>
# <li class="product_etc">TEAM CLASSIC 3930 CHIWHI GM</li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('4218',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('061001000248', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3353527&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bml8W1o%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0600010001877.jpg?1639378165" src="/shopimages/newerashop/0600010001873.jpg?1639379876"/></a>
# </div>
# <ul class="info">
# <li class="dsc">에센셜 무지 언스트럭쳐 볼캡 블랙</li>
# <li class="product_etc">940UNST ESSENTIAL BLK</li> <li class="pdt10"></li>
# <li class="price">39,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('3353527',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('060001000187', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"><img class="MK-product-icon-2" src="/shopimages/newerashop/prod_icons/27991?1640309123"/></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=4630&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=aWp3Vg%3D%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0610010002417.jpg?1550639898" src="/shopimages/newerashop/0610010002413.jpg?1562321347"/></a>
# </div>
# <ul class="info">
# <li class="dsc">MLB 팀 클래식 디트로이트 타이거즈..</li>
# <li class="product_etc">TEAM CLASSIC 3930 DETTIG HM</li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('4630',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('061001000241', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3356355&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=amh3WQ%3D%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/1010010000047.jpg?1625544511" src="/shopimages/newerashop/1010010000043.jpg?1632880996"/></a>
# </div>
# <ul class="info">
# <li class="dsc">캐주얼 클래식 뉴욕 양키스 볼캡 네..</li>
# <li class="product_etc">CSL CL NEYYAN NVY 20SS
# </li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('3356355',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('101001000004', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3359489&amp;xcode=031&amp;mcode=002&amp;scode=010&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=aW53WA%3D%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0670020000557.jpg?1612419093" src="/shopimages/newerashop/0670020000553.jpg?1612419092"/></a>
# </div>
# <ul class="info">
# <li class="dsc">버킷 햇 블랙</li>
# <li class="product_etc">BUCKET01  BLACK</li> <li class="pdt10"></li>
# <li class="price">54,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('3359489',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('067002000055', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3356357&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bmp1W11E"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/1010010000067.jpg?1670284819" src="/shopimages/newerashop/1010010000063.jpg?1670284819"/></a>
# </div>
# <ul class="info">
# <li class="dsc">캐주얼 클래식 LA다저스 볼캡 블루</li>
# <li class="product_etc">CSL CL LOSDOD DRY 20SS
#
# </li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('3356357',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('101001000006', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3353996&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bmd3UF0%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0600010002107.jpg?1670230612" src="/shopimages/newerashop/0600010002103.jpg?1670230612"/></a>
# </div>
# <ul class="info">
# <li class="dsc">잉글리쉬 풋볼 리그 토트넘 핫스퍼 F..</li>
# <li class="product_etc">940 UNST ENGLISH FOOTBALL LEAGUE..</li> <li class="pdt10"></li>
# <li class="price">43,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('3353996',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('060001000210', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>
# </td>
# <td>
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=3355939&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=a2x3UF4%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0600010003967.jpg?1582001474" src="/shopimages/newerashop/0600010003963.jpg?1582074532"/></a>
# </div>
# <ul class="info">
# <li class="dsc">MLB 마이크로 로고 LA 다저스 언스트..</li>
# <li class="product_etc">940UNST MLB MICRO LOSDOD DK RY
# </li> <li class="pdt10"></li>
# <li class="price">43,000원</li>
# <li class="info_icon" id="info_icon">
# ...
# <input id="nowBasketCount" name="nowBasketCount" type="hidden" value="0"/>
# <input id="BasketMaxCount" name="BasketMaxCount" type="hidden" value="200"/>
# <input id="listBuySelectCount" name="listBuySelectCount" type="hidden" value="N"/>
# <input id="listBuyTempid" name="listBuyTempid" type="hidden" value=""/>
# <input id="listBuyBuyOpt" name="listBuyBuyOpt" type="hidden" value="N"/>
# <input name="wish_action_type" type="hidden" value="insert"/>
# <input name="page_type" type="hidden" value="shopbrand"/>
# <input name="wish_data_type" type="hidden" value="ones"/>
# </form>
# <form action="/shop/shopbrand.html" method="post" name="hashtagform">
# <input name="search" type="hidden"/>
# <input name="search_ref" type="hidden" value="hashtag"/>
# </form>
# <script src="/js/wishlist.js?v=r216255"></script>
# <script>
#         window.addEventListener('load', function() {
#             var makeshop_wishlist = new makeshopWishlist();
#             makeshop_wishlist.init();
#             makeshop_wishlist.observer();
#         });
#     </script>
# <script src="/js/neodesign/detailpage.js?ver=r218356" type="text/javascript"></script>
# <script src="/js/neodesign/product_list.js?r=20230201141820" type="text/javascript"></script>
# <script src="/js/jquery.language.js" type="text/javascript"></script>
# <script src="/js/neodesign/basket_send.js?ver=r217045" type="text/javascript"></script>
# <script src="/js/jquery-datepicker-ko.js" type="text/javascript"></script>
# <script src="/js/shopbrand.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#
#
# function CheckKey_search() {
#     key = event.keyCode;
#     if (key == 13) {
#
#         document.search.submit();
#     }
# }
#
# function search_submit() {
#     var oj = document.search;
#     if (oj.getAttribute('search') != 'null') {
#         var reg = /\s{2}/g;
#         oj.search.value = oj.search.value.replace(reg, '');
#         oj.submit();
#     }
# }
#
# function topnotice(temp, temp2) {
#     window.open("/html/notice.html?date=" + temp + "&db=" + temp2, "", "width=450,height=450,scrollbars=yes");
# }
# function notice() {
#     window.open("/html/notice.html?mode=list", "", "width=450,height=450,scrollbars=yes");
# }
#
#         function view_join_terms() {
#             window.open('/html/join_terms.html','join_terms','height=570,width=590,scrollbars=yes');
#         }
#
#     function bottom_privacy() {
#         window.open('/html/privacy.html', 'privacy', 'height=570,width=590,scrollbars=yes');
#     }
#
#                 if (typeof wcs_do == 'function') {
#                     wcs_do();
#                 }
#
# var db = 'newerashop';
#
# var baskethidden = 'A';
#
# function send_wish_brand(idx) {
#     login_chk(); return;
#     var _form = document.product_form;
#     var _j_form = $('#product_form');
#     if (true === check_product_auth(idx, 'adult')) {
#             var adult_alert_msg = (idx == 'ALL') ? "성인인증이 필요한 상품이 포함되어 있습니다.\n성인인증페이지로 이동하시겠습니까?" : "이 상품은 성인인증이 필요합니다.\n성인인증페이지로 이동하시겠습니까?";
#     if (true === confirm(adult_alert_msg)) {
#         location.href = "/shop/adult.html?type=shopbrand&code=031&mcode=002&scode=&xtype=Y&is_list_buy=8&adult_return_url=%2Fshop%2Fshopbrand.html%3Fxcode%3D031%26mcode%3D002%26type%3DY%26gf_ref%3DYz1vU0FlS3M%3D";
#         return;
#     } else {
#         // 취소시 페이지 이동X
#         return;
#     }
#
#     }
#     if (false === create_option_input_list(_form, 'wish', idx)) {
#         return;
#     }
#
#     jQuery.ajax({
#         url  : 'wish.action.html',
#         type : 'POST',
#         data : _j_form.serializeArray(),
#         dataType: 'json',
#         success: function(response) {
#             if (response.success == true) {
#                 alert("Wish List에 등록되었습니다.\n장바구니 또는 마이페이지 상품보관함에서\n확인하실 수 있습니다.");
#             } else {
#                 if (response.message != '') {
#                     alert(response.message);
#                 }
#                 return;
#             }
#         }
#     });
#     return;
# }function login_chk() {
#     alert('회원에게만 제공이 되는 서비스입니다.\n우선 로그인을 하여 주시기 바랍니다.');
#     location.href = "/shop/member.html?type=shopbrand&code=031&mcode=002&scode=&xtype=Y";
# }
# function send_brand(temp, idx) {
#     var _form = document.product_form;
#     var _j_form = $('#product_form');
#     _form.listBuySelectCount.value = 'N'; // 선택상품값 초기화
#
#     if (temp == 'baro') {
#         _form.ordertype.value ='baro';
#         _form.ordertype.value += "|parent.|layer";
#         _form.target = "loginiframe";
#     } else {
#         _form.ordertype.value = '';
#         _form.target = "";
#     }
#     if (true === check_product_auth(idx, 'adult')) {
#             var adult_alert_msg = (idx == 'ALL') ? "성인인증이 필요한 상품이 포함되어 있습니다.\n성인인증페이지로 이동하시겠습니까?" : "이 상품은 성인인증이 필요합니다.\n성인인증페이지로 이동하시겠습니까?";
#     if (true === confirm(adult_alert_msg)) {
#         location.href = "/shop/adult.html?type=shopbrand&code=031&mcode=002&scode=&xtype=Y&is_list_buy=8&adult_return_url=%2Fshop%2Fshopbrand.html%3Fxcode%3D031%26mcode%3D002%26type%3DY%26gf_ref%3DYz1vU0FlS3M%3D";
#         return;
#     } else {
#         // 취소시 페이지 이동X
#         return;
#     }
#
#     }
#     if (false === create_option_input_list('product_form', 'basket', idx, temp)) {
#         _form.ordertype.value = '';
#         _form.target = "";
#         return;
#     }
#     _form.ordertype.value += '|parent.|layer';
#     _form.target = 'loginiframe';
#     _form.action = 'basket.html';
#     _form.list_mode.value = 'brand_basket';
#     common_basket_send(_form, true);
# } //function send_brand(temp, idx)
# function pager_move(url) {
#     // 체크박스 가상태그 있는 경우에만 사용
#     if ($(".MS_product_checkbox") != undefined) {
#         var check_cnt = 0;
#         $.each($(".MS_product_checkbox"), function() {
#             if (true == $(this).is(":checked") && $(this).attr('disabled') != 'disabled') {
#                 check_cnt++;
#             }
#         });
#         // 하나라도 체크하면 confirm창 띄움
#         if (check_cnt > 0 && (false === confirm('페이지 이동 시, 선택한 상품이 초기화 됩니다. 이동하시겠습니까?'))) return;
#     }
#     location.href = url;
# }
#
#
# function sendsort(temp) {        location.href = "/shop/shopbrand.html?xcode=031&mcode=002&type=Y&scode=&sort=" + temp + "";
# }
#
# function pagemove(temp) {
#     location.href = "/shop/shopbrand.html?xcode=031&mcode=002&type=Y&scode=&page=" + temp + "&sort=sellcnt";
# }
#
# function go_hashtag(search) {
#     document.hashtagform.search.value = search;
#     document.hashtagform.submit();
# }
#
# function hanashopfree() {
#
# }
#
# </script>
# <script src="/js/referer_cookie.js"></script>
# <script>
#         window.addEventListener('load', function() {
#             var referer_cookie = new RefererCookie();
#             referer_cookie.addService(new EnuriBrandStoreCookie());
#             referer_cookie.handler();
#         });
#     </script><script type="text/javascript">
# if (typeof getCookie == 'undefined') {
#     function getCookie(cookie_name) {
#         var cookie = document.cookie;
#         if (cookie.length > 0) {
#             start_pos = cookie.indexOf(cookie_name);
#             if (start_pos != -1) {
#                 start_pos += cookie_name.length;
#                 end_pos = cookie.indexOf(';', start_pos);
#                 if (end_pos == -1) {
#                     end_pos = cookie.length;
#                 }
#                 return unescape(cookie.substring(start_pos + 1, end_pos));
#             } else {
#                 return false;
#             }
#         } else {
#             return false;
#         }
#     }
# }
# if (typeof setCookie == 'undefined') {
#     function setCookie(cookie_name, cookie_value, expire_date, domain) {
#         var today = new Date();
#         var expire = new Date();
#         expire.setTime(today.getTime() + 3600000 * 24 * expire_date);
#         cookies = cookie_name + '=' + escape(cookie_value) + '; path=/;';
#
#         if (domain != undefined) {
#             cookies += 'domain=' + domain +  ';';
#         }  else if (document.domain.match('www.') != null) {
#             cookies += 'domain=' + document.domain.substr(3) + ';';
#         }
#         if (expire_date != 0) cookies += 'expires=' + expire.toGMTString();
#         document.cookie = cookies;
#     }
# }
#
# function setMakeshopLogUniqueId() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#         .toString(16)
#         .substring(1);
#     }
#     return s4() + s4() + s4() + s4() + s4() + s4() + s4() + s4();
# }
#
# if (getCookie('MakeshopLogUniqueId')) {
#     var MakeshopLogUniqueId = getCookie('MakeshopLogUniqueId');
# } else {
#     var MakeshopLogUniqueId = setMakeshopLogUniqueId();
#     setCookie('MakeshopLogUniqueId', MakeshopLogUniqueId);
# }
#
# function MSLOG_loadJavascript(url) {
#     var head= document.getElementsByTagName('head')[0];
#     var script= document.createElement('script');
#     script.type= 'text/javascript';
#     var loaded = false;
#     script.onreadystatechange= function () {
#         if (this.readyState == 'loaded' || this.readyState == 'complete')
#         { if (loaded) { return; } loaded = true; }
#     }
#     script.src = url;
#     head.appendChild(script);
# }
# var MSLOG_charset = "euc-kr";
# var MSLOG_server  = "/log/log24";
# var MSLOG_code = "newerashop";
# var MSLOG_var = "...";
#
# //파워앱에서만 사용
# try {
#     var LOGAPP_var = "";
#     var LOGAPP_is  = "N";
#     if (LOGAPP_is == "Y" && LOGAPP_var != "") {
#         var varUA = navigator.userAgent.toLowerCase(); //userAgent 값 얻기
#         if (varUA.match('android') != null) {
#             //안드로이드 일때 처리
#             window.android.basket_call(LOGAPP_var);
#         } else if (varUA.indexOf("iphone")>-1||varUA.indexOf("ipad")>-1||varUA.indexOf("ipod")>-1) {
#             //IOS 일때 처리
#             var messageToPost = {LOGAPP_var: LOGAPP_var};
#             window.webkit.messageHandlers.basket_call.postMessage(messageToPost);
#         } else {
#             //아이폰, 안드로이드 외 처리
#         }
#     }
# } catch(e) {}
# //파워앱에서만 사용 END
#
# if (document.charset) MSLOG_charset = document.charset.toLowerCase();
# if (document.characterSet) MSLOG_charset = document.characterSet.toLowerCase();  //firefox;
# MSLOG_loadJavascript(MSLOG_server + "/js/mslog.js?r=" + Math.random());
#
#
# </script>
# <script type="text/javascript">
# var pagekin_el = document.getElementsByTagName("div");
# var pagekin_id = [];
# for(var i=0; i < pagekin_el.length;i++){
#         if(pagekin_el[i].className.substring(0,4)=="PKMW") {
#                     pagekin_id.push(pagekin_el[i].className);
#                         }
# }
# if(pagekin_id.length>0) {
#     var script=document.createElement('script');
#     script.src='//image.makeshop.co.kr/pagekin/widget/makeshop.d.js??20230201';
#     script.charset='utf-8';
#     document.body.appendChild(script);
# }
# </script>
# <!--script type="text/javascript" src="//www.pagekin.com/widget/makeshop.js" charset="utf-8"></script-->
# <script src="/js/search_auto_complete.js?v=20210622"></script>
# <script>
#         window.addEventListener('load', function() {
#             var search_auto_completion_el = document.querySelectorAll('.search_auto_completion');
#             for (var i=0; i<search_auto_completion_el.length; i++) {
#                 var search_auto_completion = new searchAutoComplete(search_auto_completion_el[i], searchAutoCompleteOption(search_auto_completion_el[i]));
#                 search_auto_completion.init();
#             }
#
#             var smart_finder_auto_completion_el = document.querySelectorAll('.smart_finder_auto_completion');
#             for (var i=0; i<smart_finder_auto_completion_el.length; i++) {
#                 var search_auto_completion = new searchAutoComplete(smart_finder_auto_completion_el[i], {
#                     category_count: 0,
#                     link_enabled: false,
#                 });
#                 search_auto_completion.init();
#             }
#         });
#     </script><script src="/js/cookie.js" type="text/javascript"></script>
# <script type="text/javascript">
# function __mk_open(url, name, option) {
#     window.open(url, name, option);
#     //return false;
# }
#
# function action_invalidity() {
#     return false;
# }
# </script>
# <script type="text/javascript"></script><script type="text/javascript"></script><script async="true" src="//dynamic.criteo.com/js/ld/ld.js?a=7993" type="text/javascript"></script><script type="text/javascript">
# window.criteo_q = window.criteo_q || [];
# window.criteo_q.push(
#     { event : "setAccount", account : '7993' },
#
#
#     { event : "setZipcode", zipcode : "" },
#     { event : "setSiteType", type : "d" },
#     { event : "viewList", item : ["4633","3353027","3353022"], category : "MEN > 모자", keywords : "모자" }
# );
# </script>
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.agent='plmakeshop-kr';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#         document,'script','//connect.facebook.net/en_US/fbevents.js');
#     fbq('set', 'autoConfig', false, '1511777182238135');
#     fbq('init', '1511777182238135', {external_id: '0ed56a7d56a2b54e96949f6ebd93ce652b4e03e71b99a99bfad4b9aeb1782852'}, {'agent':'plmakeshop-kr'});
#     fbq('track', 'PageView', {}, {eventID: 'MS_newerashop_pageview_20230201021821_501253005'});    // ViewCategory
#     fbq('track', 'ViewCategory', {
#         content_category: '모자',
#         content_ids: ['4633','3353027','3353022','4631','5687','4218','3353527','4630','3356355','3359489','3356357','3353996'],
#         content_type: 'product'
#     }, {eventID: 'MS_newerashop_viewcategory_20230201021821_501253005'});</script>
# <!-- End Facebook Pixel Code -->
# <!-- Kakao Pixel Code -->
# <script charset="UTF-8" src="//t1.daumcdn.net/kas/static/kp.js" type="text/javascript"></script>
# <script type="text/javascript">
# kakaoPixel.setServiceOrigin('20003');
# kakaoPixel('7231124862609608075').pageView();
# </script><script type="text/javascript">
#     kakaoPixel('7231124862609608075').search({
#         keyword: ''
#     });
# </script><!-- End Kakao Pixel Code --> <script src="/js/jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
#             <!--
#                 jQuery(document).ready(function() {
#
#                     var rollover_out = '';
#
#                     jQuery('img').hover(function() {
#                         rollover_out = jQuery(this).attr('src');
#
#                         if (jQuery(this).attr('rollover_onimg')) {
#                             jQuery(this).attr('src', jQuery(this).attr('rollover_onimg'));
#                         }
#                     }, function() {
#                         if (rollover_out && jQuery(this).attr('rollover_onimg')) {
#                             jQuery(this).attr('src', rollover_out);
#                         }
#                     });
#                 });
#             //-->
#             </script><script>
#
#
# function getInternetExplorerVersion() {
#     var rv = -1;
#     if (navigator.appName == 'Microsoft Internet Explorer') {
#     var ua = navigator.userAgent;
#     var re = new RegExp("MSIE ([0-9]{1,}[\.0-9]{0,})");
#     if (re.exec(ua) != null)
#     rv = parseFloat(RegExp.$1);
#     }
#     return rv;
# }
#
# function showcherrypickerWindow(height,mode,db){
#     cherrypicker_width = document.body.clientWidth;
#     var isIe = /*@cc_on!@*/false;
#     if (isIe) {
#         cherrypicker_width = parseInt(cherrypicker_width + 18);
#     }
#     setCookie('cherrypicker_view','on', 0);
#
#
#     document.getElementById('cherrypicker_layer').style.display = "block";
#     document.getElementById('cherrypicker_layer').innerHTML = Createflash_return(cherrypicker_width,'','/flashskin/CherryPicker.swf?initial_xml=/shopimages/newerashop/cherrypicker_initial.xml%3Fv=1675228701&product_xml=/shopimages/newerashop/%3Fv=1675228701', 'cherrypicker_flash', '');
# }
#
# function load_cherrypicker(){
#     cherrypicker_check = true;
#
#     if (!document.getElementById('cherrypicker_layer')) {
#         return;
#     }
#
#
# }
# </script>
# <script type="text/javascript">
# if (document.cookie.indexOf("app_agent=power_app") >= 0) {
#
# }
# </script>
# <script src="/shopimages/newerashop/template/work/31124/common.js?r=1668753582" type="text/javascript"></script>
# </body></html>
# <!-- system by makeshop2 -->

# %%
cap_info = soup.findAll('div', {'class':'tb-center'})
cap_info[0]
# Out:
# <div class="tb-center">
# <div class="thumb">
# <a href="/shop/shopdetail.html?branduid=4633&amp;xcode=031&amp;mcode=002&amp;scode=001&amp;type=Y&amp;sort=sellcnt&amp;cur_code=031002&amp;GfDT=bmp%2BW1w%3D"><img alt="상품 섬네일" class="MS_prod_img_s" rollover_onimg="/shopimages/newerashop/0610010002407.jpg?1577324526" src="/shopimages/newerashop/0610010002403.jpg?1562321305"/></a>
# </div>
# <ul class="info">
# <li class="dsc">MLB 팀 클래식 뉴욕 양키스 게임 볼..</li>
# <li class="product_etc">TEAM CLASSIC 3930 NEYYAN GM</li> <li class="pdt10"></li>
# <li class="price">36,000원</li>
# <li class="info_icon" id="info_icon">
# <span id="btn_opt01"><img onclick="javascript:mk_prd_option_preview('4633',event,'PC');" src="//cdn3-aka.makeshop.co.kr/shopimages/newerashop/bt_opt_preview.gif?1630561940"/></span><span id="btn_opt02"><a class="btn-overlay-show" href="javascript:viewdetail('061001000240', '1', '');"><img src="//cdn3-aka.makeshop.co.kr/design/newerashop/0751decode/btn_opt02.gif"/></a></span></li>
# <li class="icon"><span class="MK-product-icons"></span></li>
# </ul>
# </div>

# %%
# url
cap_url = cap_info[0].find('a').get('href')
print(cap_url)

# 상품명
name = cap_info[0].find('li', {'class':'dsc'}).text
print(name)

# 가격
price = cap_info[0].find('li', {'class':'price'}).text
print(price)
# Out:
# /shop/shopdetail.html?branduid=4633&xcode=031&mcode=002&scode=001&type=Y&sort=sellcnt&cur_code=031002&GfDT=bmp%2BW1w%3D
# MLB 팀 클래식 뉴욕 양키스 게임 볼..
# 36,000원

# %%
name_list = []
price_list = []
url_list = []

for cap in cap_info:
    name = cap.find('li', {'class':'dsc'}).text
    price = cap.find('li', {'class':'price'}).text
    url = cap.find('a').get('href')
    print("이름: {}, 가격: {}".format(name, price))
    name_list.append(name)
    price_list.append(price)
    url_list.append(url)
# Out:
# 이름: MLB 팀 클래식 뉴욕 양키스 게임 볼.., 가격: 36,000원
# 이름: 에센셜 무지 사이즈캡 블랙, 가격: 49,000원
# 이름: 에센셜 무지 K프레임 볼캡 블랙, 가격: 39,000원
# 이름: MLB 팀 클래식 LA다저스 게임 볼캡.., 가격: 36,000원
# 이름: MLB 팀 클래식 보스턴 레드삭스 게임.., 가격: 36,000원
# 이름: MLB 팀 클래식 시카고 화이트 삭스.., 가격: 36,000원
# 이름: 에센셜 무지 언스트럭쳐 볼캡 블랙, 가격: 39,000원
# 이름: MLB 팀 클래식 디트로이트 타이거즈.., 가격: 36,000원
# 이름: 캐주얼 클래식 뉴욕 양키스 볼캡 네.., 가격: 36,000원
# 이름: 버킷 햇 블랙, 가격: 54,000원
# 이름: 캐주얼 클래식 LA다저스 볼캡 블루, 가격: 36,000원
# 이름: 잉글리쉬 풋볼 리그 토트넘 핫스퍼 F.., 가격: 43,000원
# 이름: MLB 마이크로 로고 LA 다저스 언스트.., 가격: 43,000원
# 이름: 덕 캔버스 버킷 블랙, 가격: 54,000원
# 이름: 에센셜 무지 레트로 크라운 사이즈캡.., 가격: 49,000원
# 이름: 에센셜 무지 제트캡 블랙, 가격: 43,000원
# 이름: MLB 팀 클래식 샌프란시스코 자이언.., 가격: 36,000원
# 이름: MLB 팀 클래식 샌디에이고 파드리스.., 가격: 36,000원
# 이름: MLB 마이크로 로고 LA 다저스 언스트.., 가격: 43,000원
# 이름: 잉글리쉬 풋볼 리그 토트넘 핫스퍼 F.., 가격: 49,000원
# 이름: US 빈티지 언스트럭쳐 볼캡 네이비, 가격: 43,000원
# 이름: 한화 이글스 사이즈캡, 가격: 49,000원
# 이름: MLB 팀 클래식 토론토 블루제이스 볼.., 가격: 36,000원
# 이름: MLB 메탈 뱃지 뉴욕 양키스 K프레임.., 가격: 46,000원
# 이름: NBA 베이직 시카고 불스 스냅백 블랙, 가격: 49,000원
# 이름: 에센셜 피어 오브 갓 사이즈캡 블랙, 가격: 79,000원
# 이름: MLB 메탈 뱃지 뉴욕 양키스 K프레임.., 가격: 49,000원
# 이름: 넘버 플레이트 K프레임 볼캡 블랙, 가격: 46,000원
# 이름: MLB 메탈 뱃지 뉴욕 양키스 K프레임.., 가격: 49,000원
# 이름: MLB PCV 뉴욕 양키스 로우 프로파일.., 가격: 49,000원
# 이름: 잉글리쉬 풋볼 리그 토트넘 핫스퍼 F.., 가격: 43,000원
# 이름: MLB US 플래그 뉴욕 양키스 프리 커.., 가격: 59,000원
# 이름: MLB 어센틱 뉴욕 양키스 게임 네이비, 가격: 53,000원
# 이름: 넘버 플레이트 K프레임 볼캡 네이비, 가격: 46,000원
# 이름: 에센셜 무지 레트로 크라운 스냅백.., 가격: 49,000원
# 이름: 토트넘 핫스퍼 퍼포레이티드 스냅백.., 가격: 59,000원
# 이름: 메탈리카 스케어리 가이 언스트럭쳐.., 가격: 43,000원
# 이름: MLB 팀 클래식 휴스턴 애스트로스 홈.., 가격: 36,000원
# 이름: 나일론 트랙 세일러 브림 버킷 햇 블.., 가격: 59,000원
# 이름: 밀리터리 커프 숏 비니 블랙, 가격: 36,000원
# 이름: NBA 베이직 브루클린 네츠 스냅백 블.., 가격: 49,000원
# 이름: MLB 골드 미니 메탈 뉴욕 양키스 볼.., 가격: 43,000원
# 이름: MLB 팀 클래식 탬파베이 레이스 게임.., 가격: 36,000원
# 이름: MLB 팀 클래식 애리조나 다이아몬드.., 가격: 36,000원
# 이름: 메탈리카 암즈 로고 로우 프로파일.., 가격: 59,000원
# 이름: MLB 어센틱 시카고 화이트삭스 게임.., 가격: 53,000원
# 이름: MLB 알파 인더스트리 시카고 화이트.., 가격: 49,000원
# 이름: 나일론 트랙 뉴욕 양키스 언스트럭쳐.., 가격: 43,000원
# 이름: MLB 골드 미니 메탈 뉴욕 양키스 볼.., 가격: 43,000원
# 이름: 니트 베이직 커프 비니 블랙, 가격: 29,000원
# 이름: MLB 워시드 미니 로고 LA 다저스 언.., 가격: 43,000원
# 이름: 치노 스크립트 언스트럭쳐 볼캡 블랙, 가격: 43,000원
# 이름: MLB 알파 인더스트리 LA 다저스 사이.., 가격: 49,000원
# 이름: MLB 핀치히터 LA다저스 볼캡 로얄 블.., 가격: 36,000원
# 이름: MLB 팀 클래식 애틀랜타 브레이브스.., 가격: 36,000원
# 이름: MLB 핀치히터 뉴욕 양키스 볼캡 네이.., 가격: 36,000원
# 이름: 치노 스크립트 언스트럭쳐 볼캡 다크.., 가격: 43,000원
# 이름: NBA 베이직 LA 레이커스 스냅백 바이.., 가격: 49,000원
# 이름: 토트넘 핫스퍼 퍼포레이티드 스냅백.., 가격: 59,000원
# 이름: MLB US 플래그 LA 다저스 프리 커브.., 가격: 59,000원
# 이름: MLB 화이트 온 블랙 뉴욕 양키스 볼.., 가격: 39,000원
# 이름: 나일론 트랙 제트캡 네이비, 가격: 43,000원
# 이름: MLB 팀 클래식 뉴욕 메츠 게임 볼캡.., 가격: 36,000원
# 이름: MLB US 플래그 시카고 화이트삭스 프.., 가격: 59,000원
# 이름: MLB 팀 클래식 텍사스 레인저스 볼캡.., 가격: 36,000원
# 이름: 나일론 트랙 제트캡 블랙, 가격: 43,000원
# 이름: US 빈티지 언스트럭쳐 볼캡 로얄, 가격: 43,000원
# 이름: MLB 팀 클래식 마이애미 말린스 게임.., 가격: 36,000원
# 이름: MLB 메탈 뱃지 LA 다저스 K프레임 볼.., 가격: 46,000원
# 이름: 나일론 트랙 뉴욕 양키스 레트로 크.., 가격: 49,000원
# 이름: MLB US 플래그 디트로이트 타이거즈.., 가격: 59,000원
# 이름: 와플 니트 숏 비니 블랙, 가격: 36,000원
# 이름: US 빈티지 언스트럭쳐 볼캡 스톤, 가격: 43,000원
# 이름: NYC THIN K프레임 볼캡 블랙, 가격: 46,000원
# 이름: MLB 팀 클래식 콜로라도 로키스 게임.., 가격: 36,000원
# 이름: US 빈티지 언스트럭쳐 볼캡 스칼렛, 가격: 43,000원
# 이름: 피스 더 월드 롱 바이저 레트로 크라.., 가격: 59,000원
# 이름: NBA 더 리그 골든 스테이트 워리어스.., 가격: 36,000원
# 이름: 공포의 외인구단 사이즈캡 네이비, 가격: 49,000원
# 이름: 토트넘 핫스퍼 퍼포레이티드 볼캡 네.., 가격: 49,000원
# 이름: MLB 어센틱 뉴욕 양키스 게임 로우.., 가격: 53,000원
# 이름: MLB 어센틱 샌디에이고 파드리스 게.., 가격: 53,000원
# 이름: 워시드 덕 캔버스 9FORTY 언스트럭쳐.., 가격: 43,000원
# 이름: 나일론 트랙 뉴욕 양키스 레트로 크.., 가격: 49,000원
# 이름: MLB 어센틱 샌디에이고 파드리스 게.., 가격: 53,000원
# 이름: MLB 어센틱 보스턴 레드삭스 게임 네.., 가격: 53,000원
# 이름: MLB 워시드 뉴욕 양키스 버킷 햇 블.., 가격: 59,000원
# 이름: NBA 베이직 골든 스테이트 워리어스.., 가격: 49,000원
# 이름: MLB 어센틱 피츠버그 파이어리츠 얼.., 가격: 53,000원
# 이름: NBA 베이직 보스턴 셀틱스 스냅백 그.., 가격: 49,000원
# 이름: BTS X 뉴에라 BEYOND THE SCENE 사이.., 가격: 59,000원
# 이름: 무라카미 다카시 도브 캐주얼 클래식.., 가격: 59,000원
# 이름: MLB 메리노울 립 커프 LA 다저스 비.., 가격: 49,000원
# 이름: 매트 폴리 NYC  화이트 온 블랙 K프.., 가격: 46,000원
# 이름: NBA 더 리그 밀워키 벅스 볼캡 마운.., 가격: 36,000원
# 이름: MLB 아플리케 레더 뉴욕 양키스 볼캡.., 가격: 49,000원
# 이름: 맨체스터 유나이티드 언스트럭쳐 볼.., 가격: 43,000원
# 이름: MLB 팀 클래식 시카고 컵스 게임 볼.., 가격: 36,000원
# 이름: 워시드 덕 캔버스 9FORTY 언스트럭쳐.., 가격: 43,000원
# 이름: 치노 스크립트 언스트럭쳐 볼캡 초콜.., 가격: 43,000원

# %%
df = pd.DataFrame({"이름": name_list, "가격": price_list, "url": url_list})
df.head()
# Out:
#                         이름       가격  \
# 0  MLB 팀 클래식 뉴욕 양키스 게임 볼..  36,000원
# 1           에센셜 무지 사이즈캡 블랙  49,000원
# 2        에센셜 무지 K프레임 볼캡 블랙  39,000원
# 3  MLB 팀 클래식 LA다저스 게임 볼캡..  36,000원
# 4  MLB 팀 클래식 보스턴 레드삭스 게임..  36,000원
#
#                                                  url
# 0  /shop/shopdetail.html?branduid=4633&xcode=031&...
# 1  /shop/shopdetail.html?branduid=3353027&xcode=0...
# 2  /shop/shopdetail.html?branduid=3353022&xcode=0...
# 3  /shop/shopdetail.html?branduid=4631&xcode=031&...
# 4  /shop/shopdetail.html?branduid=5687&xcode=031&...

# %% [markdown]
# ## 앞의 데이터프레임에 저장한 상품 상세페이지의 URL을 참조하여, 각각의 상품정보의 상세정보를포함하는 데이터프레임을 생성

# %%
# get html
response = requests.get(base_url + df['url'][0])

# BeautifulSoup을 활용하여 데이터 파싱
soup = BeautifulSoup(response.content, "lxml")

# %%
cap_name = soup.find('h3', {'class':'tit-prd'}).text.strip()
cap_name
# Out:
# 'MLB 팀 클래식 뉴욕 양키스 게임 볼캡 네이비'

# %%
cap_info = soup.find('tbody')
features = cap_info.findAll('div', {'class':'tb-left'})

for f in features:
    print(f.text.strip())
# Out:
# 고객안내
# 제품코드
# 10975804
# 수입원
# 뉴에라 캡 코리아
# 출시일
# 2016/06/14
# 소재
# 95%폴리에스터, 5%스판덱스
# 깊이
# 약 12cm
# 챙 길이
# 약 7cm

# %%
fic_list = []
for f in features:
    fic_list.append(f.text.strip())
fic_list
cap_dict = {'이름': cap_name}

if len(fic_list) % 2 != 0:
    fic_list = fic_list[1:] 
for i in range(len(fic_list)):
    if i % 2 == 0:
        cap_dict.update({fic_list[i]: fic_list[i+1]})
cap_dict
# Out:
# {'이름': 'MLB 팀 클래식 뉴욕 양키스 게임 볼캡 네이비',
#  '제품코드': '10975804',
#  '수입원': '뉴에라 캡 코리아',
#  '출시일': '2016/06/14',
#  '소재': '95%폴리에스터, 5%스판덱스',
#  '깊이': '약 12cm',
#  '챙 길이': '약 7cm'}

# %%
cap_df = pd.DataFrame(data = cap_dict, index = [0])
cap_df
# Out:
#                            이름      제품코드        수입원         출시일  \
# 0  MLB 팀 클래식 뉴욕 양키스 게임 볼캡 네이비  10975804  뉴에라 캡 코리아  2016/06/14
#
#                  소재      깊이   챙 길이
# 0  95%폴리에스터, 5%스판덱스  약 12cm  약 7cm

# %%
cap_detail_df = pd.DataFrame()

for i in range(len(df)):
    print(i , end='... ')
    # (1)df에 저장된 url 읽어오기
    url = df['url'][i]
    response = requests.get(base_url + url)
    soup = BeautifulSoup(response.content, "lxml")
    
    # (2)상세페이지의 정보 파싱
    cap_name = soup.find('h3', {'class':'tit-prd'}).text.strip()
    cap_info = soup.find('tbody')
    features = cap_info.findAll('div', {'class':'tb-left'})
    
    fic_list = []
    for f in features:
        fic_list.append(f.text.strip())
    
    # (3)파싱한 정보를 사용하여 딕셔너리 생성
    cap_dict = {'제품명': cap_name}
    if len(fic_list) % 2 != 0:
        fic_list = fic_list[1:] 
    for i in range(len(fic_list)):
        if i % 2 == 0:
            if fic_list[i] != '':
                cap_dict.update({fic_list[i]: fic_list[i+1]})
    
    # (4)생성한 딕셔너리로 데이터프레임 생성
    temp_df = pd.DataFrame(data = cap_dict,  index = [0])

    # (5) 데이터프레임 추가
    if len(cap_detail_df) == 0:
        cap_detail_df = temp_df
    else:
        cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# Out:
# 0... 1...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 2...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 3...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 4...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 5...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 6...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 7...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 8...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 9...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 10...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 11...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 12...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 13...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 14...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 15...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 16...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 17...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 18...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 19...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 20...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 21...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 22...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 23...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 24...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 25...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 26...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 27...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 28...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 29...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 30...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 31...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 32...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 33...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 34...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 35...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 36...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 37...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 38...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 39...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 40...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 41...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 42...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 43...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 44...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 45...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 46...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 47...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 48...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 49...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 50...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 51...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 52...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 53...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 54...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 55...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 56...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 57...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 58...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 59...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 60...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 61...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 62...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 63...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 64...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 65...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 66...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 67...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 68...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 69...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 70...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 71...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 72...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 73...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 74...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 75...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 76...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 77...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 78...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 79...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 80...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 81...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 82...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 83...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 84...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 85...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 86...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 87...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 88...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 89...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 90...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 91...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 92...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 93...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 94...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 95...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 96...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 97...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 98...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)
# 99...
# C:\Users\user\AppData\Local\Temp\ipykernel_14408\405249821.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cap_detail_df = cap_detail_df.append(temp_df, ignore_index = True)

# %%
cap_detail_df
# Out:
#                                   제품명      제품코드        수입원         출시일  \
# 0          MLB 팀 클래식 뉴욕 양키스 게임 볼캡 네이비  10975804  뉴에라 캡 코리아  2016/06/14
# 1                      에센셜 무지 사이즈캡 블랙  12359641  뉴에라 캡 코리아  2018/09/12
# 2                   에센셜 무지 K프레임 볼캡 블랙  12359612  뉴에라 캡 코리아  2020/04/14
# 3         MLB 팀 클래식 LA다저스 게임 볼캡 다크 로얄  10975815  뉴에라 캡 코리아  2016/06/14
# 4        MLB 팀 클래식 보스턴 레드삭스 게임 볼캡 네이비  10975835  뉴에라 캡 코리아  2016/06/14
# ..                                ...       ...        ...         ...
# 95           MLB 아플리케 레더 뉴욕 양키스 볼캡 블랙  13338530  뉴에라 캡 코리아     2208/27
# 96             맨체스터 유나이티드 언스트럭쳐 볼캡 블랙  12359533  뉴에라 캡 코리아  2020/01/15
# 97      MLB 팀 클래식 시카고 컵스 게임 볼캡 라이트 로얄  10975834  뉴에라 캡 코리아  2021/02/04
# 98  워시드 덕 캔버스 9FORTY 언스트럭쳐 볼캡 실란트로 그린  13086330  뉴에라 캡 코리아  2022/02/15
# 99               치노 스크립트 언스트럭쳐 볼캡 초콜렛  13086399  뉴에라 캡 코리아  2021/12/12
#
#                    소재        깊이   챙 길이   특이사항                배송비      높이   특징  \
# 0    95%폴리에스터, 5%스판덱스    약 12cm  약 7cm    NaN                NaN     NaN  NaN
# 1               100%울  약 11.5cm  약 7cm   20SS  무료 (신규회원 1회 무료교환)     NaN  NaN
# 2              100%코튼    약 12cm  약 7cm  20S/S  무료 (신규회원 1회 무료교환)     NaN  NaN
# 3    95%폴리에스터, 5%스판덱스    약 12cm  약 7cm    NaN                NaN     NaN  NaN
# 4    95%폴리에스터, 5%스판덱스    약 12cm  약 7cm    NaN                NaN     NaN  NaN
# ..                ...       ...    ...    ...                ...     ...  ...
# 95  인조가죽 (100% 폴리우레탄)    약 11cm  약 7cm   22FW  무료 (신규회원 1회 무료교환)     NaN  NaN
# 96             100%코튼       NaN  약 7cm  20S/S  무료 (신규회원 1회 무료교환)  약 11cm  NaN
# 97   95%폴리에스터, 5%스판덱스    약 12cm  약 7cm   21SS  무료 (신규회원 1회 무료교환)     NaN  NaN
# 98            100% 코튼  약 10.5cm  약 7cm   22SS  무료 (신규회원 1회 무료교환)     NaN  NaN
# 99            100% 코튼   약 9.5cm  약 7cm   22SS  무료 (신규회원 1회 무료교환)     NaN  NaN
#
#       챙
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# ..  ...
# 95  NaN
# 96  NaN
# 97  NaN
# 98  NaN
# 99  NaN
#
# [100 rows x 12 columns]

# %%
cap_detail_df['특이사항'].unique()
# Out:
# array([nan, '20SS', '20S/S', '18FW', '21SS', '19SS', '21S/S', '22SS',
#        '19SS NONE SEASON', '21FW', '2019 S/S', '22FW', 'NONESEASON',
#        'NONE'], dtype=object)

# %% [markdown]
# ## 여러 페이지의 정보를 앞의 데이터프레임에 저장한 상품 상세페이지의 URL을 참조하여, 각각의 상품정보의 상세정보를 포함하는 데이터프레임을 생성

# %%
base_url = "http://www.neweracapkorea.com"

name_list = []
price_list = []
url_list = []
index = 1

while True: 
    try :
        print('{} 페이지 파싱.....'.format(index))
        page_url = f"/shop/shopbrand.html?type=Y&xcode=031&mcode=002&sort=&page={index}"
        response = requests.get(base_url+page_url)

        # BeautifulSoup을 활용하여 데이터 파싱
        soup = BeautifulSoup(response.content, "lxml")
        cap_info = soup.findAll('div', {'class':'tb-center'})

        if len(cap_info) == 0 :
            print('끝')
            break
        for cap in cap_info:
            name = cap.find('li', {'class':'dsc'}).text
            price = cap.find('li', {'class':'price'})
            url = cap.find('a').get('href')
            #print("이름: {}, 가격: {}".format(name, price))
            name_list.append(name)
            
            if price != None :
                price_list.append(price.text)
            else :
                price_list.append('SOLD OUT')
            url_list.append(url)
        index = index + 1
    except:
        print("Unexpected error:", sys.exc_info()[0])
        break
# Out:
# 1 페이지 파싱.....
# 2 페이지 파싱.....
# 3 페이지 파싱.....
# 4 페이지 파싱.....
# 5 페이지 파싱.....
# 6 페이지 파싱.....
# 7 페이지 파싱.....
# 8 페이지 파싱.....
# 9 페이지 파싱.....
# 10 페이지 파싱.....
# 끝

# %%
df = pd.DataFrame({"이름": name_list, "가격" : price_list, "url": url_list})
df.tail()
# Out:
#                            이름        가격  \
# 892     NYC THIN 언스트럭쳐 볼캡 그레이  SOLD OUT
# 893    NYC THIN 언스트럭쳐 볼캡 다크그린  SOLD OUT
# 894      MLB 어센틱 시카고 화이트삭스 얼트  SOLD OUT
# 895   MLB 베이직 뉴욕 양키스 K프레임 볼..  SOLD OUT
# 896  MLB 베이직 LA 다저스 K프레임 볼캡..  SOLD OUT
#
#                                                    url
# 892  /shop/shopdetail.html?branduid=3365809&xcode=0...
# 893  /shop/shopdetail.html?branduid=3365810&xcode=0...
# 894  /shop/shopdetail.html?branduid=3365289&xcode=0...
# 895  /shop/shopdetail.html?branduid=3365802&xcode=0...
# 896  /shop/shopdetail.html?branduid=3365803&xcode=0...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897 entries, 0 to 896
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      897 non-null    object
#  1   가격      897 non-null    object
#  2   url     897 non-null    object
# dtypes: object(3)
# memory usage: 21.1+ KB
