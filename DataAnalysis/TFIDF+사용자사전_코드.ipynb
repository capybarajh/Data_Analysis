# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import re
import konlpy
from nltk import download
import nltk
from nltk.tokenize import RegexpTokenizer
from PIL import Image
from wordcloud import WordCloud
from collections import Counter
import itertools

# %%
df = pd.read_excel('./원본데이터/0105_0112.xlsx')
df
# Out:
#                                                     내용
# 0    최신 헨리여권지수에 따르면 일본이 193개국에 무비자 입국을 허용하면서 세계에서 가...
# 1    팝 음악에서 수상에 빛나는 드라마와 영화(기생충, 오징어 게임 등)에 이르기까지, ...
# 2    꿈꾸는 밤 외출이 그릴에서 갓 구워낸 고기와 김치 반찬, 노래방인가?\n \n 코리...
# 3    오스카상 후보에 올랐던 고레에다 히로카즈 감독의 2018년작 <어느 가족>은 거짓말...
# 4    세계의 많은 사람들이 방탄소년단과 블랙핑크와 같은 슈퍼스타의 팝 음악 퍼포먼스를 통...
# ..                                                 ...
# 96   코로나19 여파로 2년여간 중단됐던 얼음낚시축제가 올해 화천에서 열린다. 23일간 ...
# 97   한국 남자 하키 주장 이남용은 팀이 경험이 많고 2023 부바네스와르-루르켈라 FI...
# 98   한국의 김톰(김주형)은 1라운드 65타에 4언더파 69타를 추가해 12언더파가 됐고...
# 99   대립되는 요소들의 조화로 구성된 나라인 한국은 우리를 놀라게 한다. 한국의 다이내믹...
# 100  번째 소식입니다. 한국의 연예인들이 제37회 골든디스크어워즈 참석을 위해 태국을 방...
#
# [101 rows x 1 columns]

# %%
# director_df = df[df['내용'].str.contains('게임')]
# director_df = director_df.reset_index(drop=True)

# %%
# w = list(director_df['내용'])
# for i in range(len(w)):
#     w[i] = str(w[i])
# content = ' '.join(w)
# content

# %% [markdown]
# ### 한국어

# %%
from konlpy.tag import Komoran
kor_stopwords = ['한국', '한국의']

komoran = konlpy.tag.Komoran()
komoran = Komoran(userdic='user_dict.txt')

# %%
kor_total = []
for news in df['내용']:
    temp = []
    news = news.replace('.', '').replace(',','').replace("'","").replace('·', ' ').replace('=','').replace('\n','').replace('\t','').replace('\r','')
    pos_news = [t for t in komoran.nouns(news)]
    for i in range(len(pos_news)):
        if pos_news[i] not in kor_stopwords:
            temp.append(pos_news[i])
    kor_total.append(' '.join(temp))
print(kor_total)
# Out:
# ['최신 헨리 여권 지수 일본 개국 비자 입국 허용 세계 여권 년 시작 일본 지수 년 연속 위 차지 여행 산업 코로나 유행 반등 사용 것 일본 외교부 입수 수 최신 수치 년 말 일본 국민 소지 유효 여권 장 전년도 대비 명 이상 감소 것 여권 인구 미만 의미 싱가포르 지수 공동 위 차지 독일 스페인 기타 유럽 국가 뒤 개 국가 무비 자로 여행 수 미국 스위스 뉴질랜드 노르웨이 위 중국 볼리비아 개 국가 무비 자로 여행 수 러시아 상황 개 국가 무비 자로 여행 수 아프가니스탄 개 국가 무비 자로 여행 수 것 런던 본사 이민 컨설팅 회사 헨리 앤드 발표 순위 국제항공운송협회 데이터 사용 개 목적지 접근 수 개 여권 접근 순위 방법 금융 자문 사이 자 아랍 엘
 세계 성공 개봉 성적 오스카 시상식 국제 작품상 후보 박찬욱 감독 주목 차례 헤어질 결심 형사 박해일 살인 사건 수사 현대식 필름 느와르 묘사 박찬욱 감독 말 느와르 장르 현대 표현 시작 게 느와르 장르 시작 너머 말 관객 기대 것 이상 장르 확장 것 박찬욱 감독 작품 팬 기대 것 공동경비구역 JSA 복수는 나의 것 친절한 금자씨 사이보그 지만 괜찮아 스토커 올드보이 박찬욱 감독 카메라 동적 데 스타일 리스트 이자 매혹 섹스 극단 폭력 발산 명성 년 평단 극찬 아가씨 박찬욱 감독 식민지 시대 배경 반전 줄거리 노골적 섹스 이중 교차 사랑 요소 관객 겹 추가 박찬욱 감독 헤어질 결심 사랑 이야기 박찬욱 감독 영화 전 사랑 이야기 모두 말 라고 속 생각 영화 폭력 섹스 등장 때문 생각 사람 영화 사랑 이야기 무시 말 박찬욱 감독 베일 사람 이야기 안 로맨스 이야기 것 것 영화 사람 인식 지배 폭력 과도 노출 사람 안 로맨스 이야기 수 것 때문 말 박찬욱 감독 헤어질 결심 분석 흥미 이야기 번 부분 이상 의심 긴장감 여성 남편 이상 지점 이상 필름 느와르 미스터리 영화 질문 여자 도시 이사 형사 이사 도시 선택 말 헤어질 결심 년 칸 영화제 성공 세상 선 박찬욱 감독 감독상 수상 박찬욱 감독 칸 영화제 번 후보 바 박쥐 올드보이 바 박찬욱 감독 헤어질 결심 것 치료 형태 말 런던 미니시리즈 작업 당시 해외 체류 곳 개 에피소드 감독 것 육체 고통 후반 작업 때 심리 피곤 향수병 상태 말 박찬욱 감독 영국 동안 친절한 금자씨 아가씨 박쥐 사이보그 지만 괜찮아 등 작업 정 서경 작가 의지 서로 생각 사유 상대방 시작 문장 작업 능력 고도 발달 정 서경 작가 박찬욱 감독 작품 기여 박찬욱 감독 정 서경 작가 가족 휴가 목적 기분 가족 런던 여행 인정 다음 영화 이야기 ...

# %% [markdown]
# ### 영어

# %%
eng_stopwords = ['The', 'the', 'korean', 'Korean','korea','Korea','kore','Kore','top','TOP']
eng_total = []

# 3글자 이상
tokenizer = RegexpTokenizer("[\w']{3,}")

# %%
for news in df['내용']:
    temp = []
    news = news.replace('.', '').replace(',','').replace("'","").replace('·', ' ').replace('=','')
    news = re.sub('[^a-zA-Z ]', '', news).strip()
    pos_news = [t for t in tokenizer.tokenize(news)]
    for i in range(len(pos_news)):
        if pos_news[i] not in eng_stopwords:
            temp.append(''.join(pos_news[i]))
    eng_total.append(' '.join(temp))

# %% [markdown]
# ### 한국어 + 영어 합치기

# %%
total = []
for i in range(len(df)):
    temp = []
    temp.append(kor_total[i])
    temp.append(eng_total[i])
    total.append(' '.join(temp))

# %%
#TfidfVectorizer

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(total)

# %%
tfidf_weights = [(word, tfidf.getcol(idx).sum()) for word, idx in vectorizer.vocabulary_.items()]
tfidf_weights[0:10]
# Out:
# [('최신', 0.4779042683108703),
#  ('헨리', 0.3085385270793207),
#  ('여권', 0.6609341226840313),
#  ('지수', 1.1599315594504183),
#  ('일본', 2.3579389262075345),
#  ('개국', 0.4220190964333798),
#  ('비자', 0.3307235692422809),
#  ('입국', 0.3487533914179155),
#  ('허용', 0.0992677827841725),
#  ('세계', 2.183660299991135)]

# %%
df = pd.DataFrame(tfidf_weights, columns = ['word', 'tfidf'])
df = df.sort_values('tfidf', ascending=False)
df = df.reset_index(drop=True)
df
# Out:
#       word     tfidf
# 0       영화  3.420333
# 1       감독  3.051510
# 2       선수  2.880735
# 3      드라마  2.743908
# 4     넷플릭스  2.537794
# ...    ...       ...
# 5074    가와  0.016366
# 5075  브라이언  0.016366
# 5076   유해준  0.016366
# 5077    이일  0.016366
# 5078   gpa  0.016366
#
# [5079 rows x 2 columns]

# %%
final = df.head(300)
final_dict = final.set_index('word').to_dict()['tfidf']
final_dict
# Out:
# {'영화': 3.4203332751746753,
#  '감독': 3.051510166457372,
#  '선수': 2.8807354851418037,
#  '드라마': 2.743908182560905,
#  '넷플릭스': 2.537793692160041,
#  '일본': 2.3579389262075345,
#  '세계': 2.183660299991135,
#  '축제': 2.133324017512187,
#  '방탄소년단': 2.1033528375622406,
#  '사람': 2.0212065961932977,
#  '블랙핑크': 1.9131522107509935,
#  '그룹': 1.8799669187575678,
#  '콘텐츠': 1.8356280995597802,
#  '작품': 1.797648293596508,
#  '음식': 1.7542714180060033,
#  '필리핀': 1.7278753270461915,
#  '자신': 1.645810966865847,
#  '서울': 1.6038741448003857,
#  '이야기': 1.6000514197126903,
#  '1월': 1.5929491230070645,
#  '시작': 1.5838980595234233,
#  '인기': 1.5559099503411127,
#  '한류': 1.5510264820743518,
#  '문화': 1.437935093418405,
#  '방문': 1.4198947550101706,
#  '행사': 1.3885465112029338,
#  '농구': 1.3834688571172715,
#  '북한': 1.3697867542384046,
#  '요리': 1.3689103614818885,
#  '국가': 1.3597625637348683,
#  '공연': 1.3556239043159248,
#  '미국': 1.3132683065767554,
#  '박찬욱': 1.3129321400696574,
#  '태국': 1.3096058147370884,
#  '관광객': 1.2942926368788867,
#  '활동': 1.283286128997064,
#  '코로나': 1.278726089445934,
#  '이다': 1.2623195595366368,
#  '시간': 1.2606454161493617,
#  '전통': 1.2473319494208173,
#  '올해': 1.2307162005488248,
#  '발표': 1.1890046290926173,
#  '김치': 1.1748459493846954,
#  '지역': 1.1704176681681961,
#  '여행': 1.1669796427086774,
#  '지수': 1.1599315594504183,
#  '이번': 1.1544161994510926,
#  '결심': 1.143156636034303,
#  '헤어질': 1.143156636034303,
#  '차지': 1.1416549785674803,
#  '발타자': 1.1260738723751118,
#  '성공': 1.1084069732223434,
#  '개최': 1.1026009083122417,
#  '베트남': 1.0999068068047722,
#  '동안': 1.0957426028849149,
#  '배우': 1.092683454816171,
#  '영입': 1.0919170722426776,
#  '스타': 1.0789044819425586,
#  '공개': 1.0753760702556396,
#  '커피': 1.062707239646927,
#  '기록': 1.057459461685179,
#  '한국': 1.0545526455718206,
#  '달러': 1.0529283855574165,
#  '예정': 1.0499799515804256,
#  '이후': 1.0211742299027224,
#  '수원': 1.009378959162196,
#  '참석': 0.992681781073336,
#  '19': 0.9858987046860785,
#  '사랑': 0.9808493902592452,
#  '콘서트': 0.9801644137684586,
#  '경기': 0.9713841963587977,
#  '연습': 0.9573640318965342,
#  '한국인': 0.946359240389,
#  '참가자': 0.9436530975976893,
#  '때문': 0.9315771027163482,
#  '얼음': 0.9308786609078278,
#  '중국': 0.9293328888449539,
#  '멤버': 0.9288230610234663,
#  '앨범': 0.9107635502797182,
#  'bts': 0.9071186060917825,
#  '경험': 0.8942409406693651,
#  '역사': 0.8812876099122305,
#  '최고': 0.8785411548413816,
#  '월드컵': 0.874689137001455,
#  '회사': 0.8713284673307706,
#  '영상': 0.8687859951459963,
#  '정부': 0.8687414736773733,
#  '계획': 0.8632476881363306,
#  '관계': 0.8602939621728968,
#  '물고기': 0.8598843620608494,
#  '화천': 0.8492710670890767,
#  '대회': 0.8421038913541492,
#  '산천어축제': 0.8413086872398283,
#  '훈련': 0.841307141405711,
#  '아침': 0.8367707579579068,
#  '음악': 0.8350779706219598,
#  '투어': 0.8325085499173889,
#  '시즌': 0.8313328331568267,
#  '낚시': 0.8264559848866746,
#  '산천어': 0.8222757144804448,
#  '시드': 0.8212187713757662,
#  '리그': 0.8193635053942774,
#  '제작': 0.8152602866225946,
#  '처음': 0.8147378085080443,
#  '국제': 0.81417486345932,
#  '관광': 0.8135834911603204,
#  '식사': 0.8111815362734516,
#  '데뷔': 0.8106751993014931,
#  '부문': 0.8098891770328349,
#  '대통령': 0.8064073921852577,
#  '후보': 0.7981457102574274,
#  '생각': 0.7975409849335514,
#  '최근': 0.7876104401927985,
#  '코리안': 0.7816577315980395,
#  '대표': 0.7782768302865161,
#  '케이': 0.7749120127101706,
#  '얼음낚시': 0.7728930307162308,
#  '도착': 0.7651146025626472,
#  '정이': 0.7609683736252911,
#  '아카데미': 0.7592721360174511,
#  '이상': 0.7571958094465576,
#  '시상식': 0.7532155830052809,
#  '12월': 0.7511976699110637,
#  '나라': 0.7473160566935378,
#  '도시': 0.7469615592099186,
#  '토너먼트': 0.746445761918652,
#  '글로리': 0.7394762042327606,
#  '사용': 0.7377945234838847,
#  '가족': 0.7374817446894469,
#  '솔로': 0.7344991874960187,
#  '선택': 0.7333987513645193,
#  '채소': 0.7332250697451341,
#  '기생충': 0.7318351018498774,
#  '웹툰': 0.7270522623440099,
#  '의상': 0.7253639398701259,
#  '현대': 0.725240493297078,
#  '진행': 0.7239724719321667,
#  '사회': 0.7236526035210081,
#  '다음': 0.7211438522667697,
#  'ildefonso': 0.7183341905173094,
#  '중단': 0.7182196498396414,
#  '비행기': 0.7146244821881194,
#  '한국프로농구': 0.7127077216703692,
#  '참여': 0.7108513940998709,
#  '월드': 0.6969212370938441,
#  '준비': 0.6897243399641496,
#  '게임': 0.6886101266995721,
#  '고기': 0.6870478662397748,
#  '공식': 0.6858877034750337,
#  '문제': 0.6817032447619511,
#  '아이돌': 0.6809967191714409,
#  '패션': 0.6766395592868547,
#  '해당': 0.6729217838259023,
#  '일부': 0.6700024481679359,
#  '시도': 0.6641009391935515,
#  '시리즈': 0.6613677518350263,
#  '여권': 0.6609341226840313,
#  '양국': 0.6581563526685144,
#  '무대': 0.6570275917025522,
#  '등장': 0.6557798240996182,
#  '카페': 0.655133380574189,
#  '바둑': 0.654628785260367,
#  '출연': 0.6530532661436227,
#  '맨손': 0.6518572653175101,
#  '리사': 0.6462968709807486,
#  '모습': 0.6437853275680121,
#  '미술관': 0.6417636016025592,
#  '이미지': 0.6393930817305896,
#  '소녀': 0.6393726191328902,
#  '아시아': 0.6383358365535752,
#  '대학교': 0.6361285367998268,
#  '주연': 0.6340649234731176,
#  '구멍': 0.6307991944656199,
#  '관객': 0.6297002332637479,
#  '관심': 0.6296926148978174,
#  '산업': 0.6292098828001335,
#  '시청': 0.628920317362242,
#  '페어': 0.6285367569888831,
#  '제공': 0.6282835592613167,
#  '장르': 0.6258233855079294,
#  '현지': 0.6247570375999902,
#  '스페인': 0.6237326034222817,
#  '화천군': 0.620516986333187,
#  '언더': 0.6162753882735591,
#  '차비': 0.615823532549225,
#  '프로그램': 0.6152181904315261,
#  '기대': 0.6151310565836381,
#  '설명': 0.6151120764795637,
#  '결과': 0.6144165432228044,
#  '수상': 0.6124518174935123,
#  '마을': 0.6105319099604128,
#  '규모': 0.6094562814608112,
#  '오징어': 0.6078577493690417,
#  '발전': 0.6048268990131748,
#  '홍보': 0.601725244890646,
#  '외국인': 0.5972634857584912,
#  '여성': 0.5970270554586488,
#  '저자': 0.5939833724427762,
#  '부산': 0.5937207624745277,
#  '제니': 0.5903957941885448,
#  '정도': 0.5887554310112696,
#  '계속': 0.5877731755923092,
#  '벨기에': 0.5871385674783446,
#  '지원': 0.5859483295385868,
#  '원작': 0.582740380317359,
#  '방법': 0.5822489515284459,
#  '남자': 0.5819191844411808,
#  '한복': 0.5817547327766638,
#  '전시': 0.5783526996372207,
#  '10': 0.5780625938306083,
#  '아티스트': 0.5734670096547791,
#  '보도': 0.5690348931859325,
#  '위치': 0.5651470014437794,
#  '차트': 0.5641801065944654,
#  '수집': 0.5635089235139001,
#  '복수': 0.5623936525847477,
#  '예술': 0.5600223414373863,
#  '특색': 0.5594563758270112,
#  '사진': 0.5574651113619431,
#  '형사': 0.5574621235332435,
#  '대부분': 0.556565538311832,
#  '필요': 0.5552786819544613,
#  '양념': 0.5507560228078299,
#  '마인츠': 0.5491944395614847,
#  '유행': 0.5487947131686726,
#  '경우': 0.5476259102468531,
#  '주최': 0.5464556614087451,
#  '차례': 0.5453623806662211,
#  '연구원': 0.5448509961793377,
#  '정국': 0.5446318966438988,
#  '갤러리': 0.5446219111600733,
#  '승객': 0.5440444530009296,
#  '목표': 0.543270600627618,
#  '송어': 0.541781842050415,
#  '전시회': 0.5413771268245015,
#  '로맨스': 0.5405148735947283,
#  'university': 0.5384457076376088,
#  '도움': 0.5364441077598598,
#  '이정재': 0.5355646391612764,
#  '한국어': 0.5340919010025881,
#  '여행객': 0.5334833180971998,
#  '추가': 0.5329139772625906,
#  '재료': 0.5311258977253988,
#  '포함': 0.5308777524435286,
#  '판매': 0.530606535767923,
#  '순위': 0.5299162973974034,
#  '인도': 0.5283019932305634,
#  '줄거리': 0.5275414796803612,
#  '연기': 0.5252932424389644,
#  '브랜드': 0.5239875532480844,
#  '내일': 0.5215295510489074,
#  '거리': 0.5193642082381766,
#  '네오': 0.5184399399104833,
#  '기업': 0.5181645080410593,
#  '단어': 0.5150697606542717,
#  '사이': 0.5148833270330142,
#  '수업': 0.5130587673486049,
#  '의미': 0.5106456942080332,
#  '노력': 0.5099293024294425,
#  '선정': 0.5078501227220242,
#  '요소': 0.5075703508875689,
#  '스트리밍': 0.5070927795986566,
#  '구단': 0.5069812483216134,
#  '사실': 0.5067722147389928,
#  '친구': 0.505333993401577,
#  '수출': 0.5052823075364002,
#  '최대': 0.5049252040346457,
#  '가지': 0.5039466644569645,
#  '방문객': 0.5030704168399777,
#  '마늘': 0.5030108673705033,
#  '온라인': 0.5026805728196356,
#  '시눌룩': 0.5021536280306657,
#  '노래': 0.5021241755638783,
#  '아테': 0.501876245157628,
#  '공유': 0.5008563178660921,
#  '확대': 0.4984360688527125,
#  '활용': 0.4982140410956649,
#  '페이스트리': 0.49819360273882135,
#  '참가': 0.4956944562839975,
#  '조치': 0.4952296450511496,
#  '목적지': 0.4926890528901061,
#  '강남': 0.4924345804316484,
#  '배경': 0.49241935731877895,
#  '마지막': 0.4913743908682913,
#  '해외': 0.4899856749844771,
#  '엔터테인먼트': 0.4892331220756949,
#  '저스틴': 0.4888374154467001,
#  '있다': 0.4885206611201206,
#  '안전': 0.4884895744106763,
#  '여행자': 0.48847124529211156,
#  '손님': 0.48779443032900827,
#  '대화': 0.487668974906596,
#  '팬데믹': 0.48508490098443247,
#  '남성': 0.48281416751985756,
#  '결정': 0.48255597624392654,
#  '플랫폼': 0.4820371758766608,
#  '호주': 0.48099483583069347,
#  '평판': 0.48084146440867154,
#  '소속': 0.4804201670049921,
#  '국립경기장': 0.47965105626114923}

# %%
im = Image.open('mask.png') # 이미지 파일 읽어오기
mask_arr = np.array(im) # 픽셀 값 배열 형태 변환

sns.set_style('white')
font_path = 'C:\Windows\Fonts\HMFMMUEX.TTC'

#prefer_horizontal=Ture -> 글씨 똑바르게 나오게 하기
wc = WordCloud(font_path=font_path, width=1500, height=1200, background_color='white', colormap='Set2', mask=mask_arr, prefer_horizontal=True).fit_words(final_dict)

plt.figure(figsize = (20, 20))  
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
# End of File
