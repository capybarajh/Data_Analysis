# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc
# %matplotlib inline

# %%
directory1='프로젝트 파일\\2021 지역사회조사(60세 이상) 수정\\'
directory2='프로젝트 파일\\202106 노인기초연금 수급 현황\\'
directory3='프로젝트 파일\\고령자 고용정보\\'
directory4='프로젝트 파일\\고령자 인구\\'
directory5='프로젝트 파일\\독거노인 현황\\'
directory6='프로젝트 파일\\사회적 신뢰도\\'
directory7='프로젝트 파일\\일반수급자 현황\\'

# %%
data1=pd.read_csv(directory1+"60세 이상 설문자의 개인 정보.csv")
data2=pd.read_csv(directory1+"60세 이상 소득 만족도.csv")
data3=pd.read_csv(directory1+"60세 이상 여가활동 만족도.csv")
data4=pd.read_csv(directory1+"60세 이상 일자리 만족도.csv")
data5=pd.read_csv(directory1+"60세 이상 주거환경 만족도.csv")
data6=pd.read_csv(directory1+"60세 이상 삶의 만족도 행복도.csv")

# %%
data1
# Out:
#          ID   GU  FAM1  FAM15  SQ0_2  SQ0_3  TE1  AAQ1   MTE9  MBQ5  JEW1  \
# 0         1  110     2      2      1      1    1     7  45.00    15     1
# 1         1  110     2      2      1      1    2     7  45.00    15     2
# 2        12  110     2      2      1      1    1     6  47.00    25     1
# 3        12  110     2      2      1      1    2     6  33.00    25     2
# 4        15  110     2      2      1      1    1     8  50.00    10     1
# ...     ...  ...   ...    ...    ...    ...  ...   ...    ...   ...   ...
# 9094  78065  290     2      2      2      1    6     7  45.00    45     2
# 9095  78090  305     5      2      1      1    6     7  30.50    28     1
# 9096  78117  410     3      3      2      1    1    10  50.00    10     1
# 9097  78117  410     3      3      2      1    2    10  50.00    20     2
# 9098  78140  350     2      2      2      1    1     4  55.25    26     2
#
#       JEW2  JEW3  JEW4  JEW5      wta2         wtb1      wtb2
# ...

# %%
data2.drop(['ID','GU'],axis=1,inplace=True)
data3.drop(['ID','GU'],axis=1,inplace=True)
data4.drop(['ID','GU'],axis=1,inplace=True)
data5.drop(['ID','GU'],axis=1,inplace=True)
data6.drop(['ID','GU'],axis=1,inplace=True)

# %%
projectdata=pd.concat([data1,data2,data3,data4,data5,data6],axis=1)
projectdata.drop(['ID'],axis=1,inplace=True)

# %%
corrdata=projectdata.drop('GU',axis=1)

# %%
#삶의 만족도와 행복도
corrdata1=corrdata[['FAM1','FAM15','SQ0_3','AAQ1','BQ1_1','BQ1_2','BQ1_3','BQ1_4']]
cor1=corrdata1.corr(method='spearman')

# %%
def corhmap(cor):
    mask=np.zeros_like(cor, dtype=np.bool)
    mask[np.triu_indices_from(mask)]=True

    figure, ax=plt.subplots()
    figure.set_size_inches(20,10)
    sns.heatmap(cor,mask=mask,vmin=-1, vmax=1, square=True, annot=True)
    plt.show()

# %%
corhmap(cor1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9984\3155335759.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)

# %%
#소득 만족도
corrdata2=corrdata[['FAM1','FAM15','SQ0_3','AAQ1','BQ2','BQ3']]
cor2=corrdata2.corr(method='spearman')

# %%
corhmap(cor2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9984\1823761758.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)

# %%
#여가활동 만족도
corrdata3=corrdata[['FAM1','FAM15','SQ0_3','AAQ1','AQ11_1','AQ15']]
cor3=corrdata3.corr(method='spearman')

# %%
corhmap(cor3)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9984\1823761758.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)

# %%
#일자리 만족도(일을 하는 사람 대상)
corrdata4=corrdata[corrdata['BQ7']==1][['FAM1','FAM15','AAQ1','BQ6','BQ7B_1','BQ7B_2','BQ7B_3','BQ7B_4','BQ7B_5']]
cor4=corrdata4.corr(method='spearman')

# %%
corhmap(cor4)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9984\1823761758.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)

# %%
#5.주거환경
corrdata5=corrdata[['FAM1','FAM15','SQ0_3','AAQ1','BQ4_1','BQ4_2','BQ4_3']]
cor5=corrdata5.corr(method='spearman')

# %%
corhmap(cor5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9984\1823761758.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)

# %%
#6. 삶의 만족도&행복도와 소득, 여가활동
corrdata6=corrdata[['FAM1','FAM15','SQ0_3','AAQ1','BQ1_1','BQ1_2','BQ1_3','BQ1_4','BQ2','BQ3','AQ11_1','AQ15']]
cor6=corrdata6.corr(method='spearman')

# %%
corhmap(cor6)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9984\1823761758.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)

# %%
# 양상관성
#1.전반적인 삶의 만족도와 문화여가시설만족도(0.34)
#2.현재 살고 있는 지역에 대한 전반적인 생활 만족도와 문화여가시설만족도(0.36)
#3.

# 음상관성
#1.전반적인 삶의 만족도와 생계유지어려움 경험정도(-0.33)
#2.현재 살고 있는 지역에 대한 전반적인 생활 만족도와 생계유지 어려움 경험정도(-0.3)

# %%
#요인들,기초생활수급자,최저생계비,

# %%
#7. 일자리와 주거환경()
corrdata7=corrdata[corrdata['BQ7']==1][['FAM1','FAM15','AAQ1','BQ6','BQ7B_1','BQ7B_2','BQ7B_3','BQ7B_4','BQ7B_5','BQ4_1','BQ4_2','BQ4_3']]
cor7=corrdata7.corr()

# %%
corhmap(cor7)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9984\1823761758.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)

# %%
pcadata1=corrdata1[['BQ1_1','BQ1_2','BQ1_3']]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

#SCREEPLOT

std=StandardScaler().fit_transform(pcadata1)
pca=PCA()
pca.fit_transform(std)

compname="principal component"
variance=pd.DataFrame(pca.explained_variance_,index=[compname+" "+str(i) for i in range(1,pcadata1.shape[1]+1)],columns=["PCA explained variance"])
varratio=pd.DataFrame(pca.explained_variance_ratio_,index=[compname+" "+str(i) for i in range(1,pcadata1.shape[1]+1)],columns=["PCA explained variance_ratio"])
cumratio=pd.DataFrame(pca.explained_variance_ratio_.cumsum(),index=[compname+" "+str(i) for i in range(1,pcadata1.shape[1]+1)],columns=["Cum Ratio"])

pcasum=pd.concat([variance,varratio,cumratio],axis=1)
print(pcasum)
plt.figure(figsize=(20,10))
plt.rc('font',size=20)
plt.plot(pca.explained_variance_,'o-',color='red')
plt.title("Scree Plot")
#plt.axhline(y=1,linewidth=2,color='blue')
plt.axvline(x=pcasum[pcasum['Cum Ratio']<=0.85].shape[0])
plt.show()
print("적절한 주성분 개수 : ",pcasum[pcasum['Cum Ratio']<=0.85].shape[0],"개")
# Out:
#                        PCA explained variance  PCA explained variance_ratio  \
# principal component 1                2.419922                      0.806552
# principal component 2                0.337828                      0.112597
# principal component 3                0.242580                      0.080851
#
#                        Cum Ratio
# principal component 1   0.806552
# principal component 2   0.919149
# principal component 3   1.000000
# 적절한 주성분 개수 :  1 개

# %%
from pca import pca
model=pca(n_components=2)
model.fit_transform(std)
fig,ax=model.biplot(n_feat=1,legend=False)
# Out:
# [pca] >Column labels are auto-completed.
# [pca] >Row labels are auto-completed.
# [pca] >The PCA reduction is performed on the [3] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
# [pca] >Plot PC1 vs PC2 with loadings.

# %%
#제1주성분과 1번 컬럼이 가장 상관관계가 있으므로 1번 컬럼인 'BQ1_1'로 축소할 수 있다,
pca1=corrdata1['BQ1_1']

# %%
pcadata2=corrdata4[['BQ7B_1','BQ7B_2','BQ7B_3','BQ7B_4','BQ7B_5']]

# %%
std=StandardScaler().fit_transform(pcadata2)
pca=PCA()
pca.fit_transform(std)

compname="principal component"
variance=pd.DataFrame(pca.explained_variance_,index=[compname+" "+str(i) for i in range(1,pcadata2.shape[1]+1)],columns=["PCA explained variance"])
varratio=pd.DataFrame(pca.explained_variance_ratio_,index=[compname+" "+str(i) for i in range(1,pcadata2.shape[1]+1)],columns=["PCA explained variance_ratio"])
cumratio=pd.DataFrame(pca.explained_variance_ratio_.cumsum(),index=[compname+" "+str(i) for i in range(1,pcadata2.shape[1]+1)],columns=["Cum Ratio"])

pcasum=pd.concat([variance,varratio,cumratio],axis=1)
print(pcasum)
plt.figure(figsize=(20,10))
plt.rc('font',size=20)
plt.plot(pca.explained_variance_,'o-',color='red')
plt.title("Scree Plot")
#plt.axhline(y=1,linewidth=2,color='blue')
plt.axvline(x=pcasum[pcasum['Cum Ratio']<=0.85].shape[0])
plt.show()
print("적절한 주성분 개수 : ",pcasum[pcasum['Cum Ratio']<=0.85].shape[0],"개")
# Out:
#                        PCA explained variance  PCA explained variance_ratio  \
# principal component 1                3.215860                      0.643029
# principal component 2                0.594875                      0.118948
# principal component 3                0.521670                      0.104311
# principal component 4                0.378084                      0.075600
# principal component 5                0.290622                      0.058112
#
#                        Cum Ratio
# principal component 1   0.643029
# principal component 2   0.761978
# principal component 3   0.866288
# principal component 4   0.941888
# principal component 5   1.000000
# 적절한 주성분 개수 :  2 개

# %%
from pca import pca
model=pca(n_components=2)
model.fit_transform(std)
fig,ax=model.biplot(n_feat=2,legend=False)
# Out:
# [pca] >Column labels are auto-completed.
# [pca] >Row labels are auto-completed.
# [pca] >The PCA reduction is performed on the [5] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
# [pca] >Plot PC1 vs PC2 with loadings.

# %%
#제1주성분과 5번 컬럼이 가장 상관관계가 있고 2주성분과 3번 컬럼이 상관관계가 있으므로 BQ7B_3, BQ7B_5변수를 뽑을 수 있다.
pca2=corrdata4[['BQ7B_3', 'BQ7B_5']]

# %%
pcadata3=corrdata5[['BQ4_1','BQ4_2','BQ4_3']]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

#SCREEPLOT

std=StandardScaler().fit_transform(pcadata3)
pca=PCA()
pca.fit_transform(std)

compname="principal component"
variance=pd.DataFrame(pca.explained_variance_,index=[compname+" "+str(i) for i in range(1,pcadata3.shape[1]+1)],columns=["PCA explained variance"])
varratio=pd.DataFrame(pca.explained_variance_ratio_,index=[compname+" "+str(i) for i in range(1,pcadata3.shape[1]+1)],columns=["PCA explained variance_ratio"])
cumratio=pd.DataFrame(pca.explained_variance_ratio_.cumsum(),index=[compname+" "+str(i) for i in range(1,pcadata3.shape[1]+1)],columns=["Cum Ratio"])

pcasum=pd.concat([variance,varratio,cumratio],axis=1)
print(pcasum)
plt.figure(figsize=(20,10))
plt.rc('font',size=20)
plt.plot(pca.explained_variance_,'o-',color='red')
plt.title("Scree Plot")
#plt.axhline(y=1,linewidth=2,color='blue')
plt.axvline(x=pcasum[pcasum['Cum Ratio']<=0.85].shape[0])
plt.show()
print("적절한 주성분 개수 : ",pcasum[pcasum['Cum Ratio']<=0.85].shape[0],"개")
# Out:
#                        PCA explained variance  PCA explained variance_ratio  \
# principal component 1                1.936886                      0.645558
# principal component 2                0.668112                      0.222680
# principal component 3                0.395331                      0.131763
#
#                        Cum Ratio
# principal component 1   0.645558
# principal component 2   0.868237
# principal component 3   1.000000
# 적절한 주성분 개수 :  1 개

# %%
from pca import pca
model=pca(n_components=2)
model.fit_transform(std)
fig,ax=model.biplot(n_feat=1,legend=False)
# Out:
# [pca] >Column labels are auto-completed.
# [pca] >Row labels are auto-completed.
# [pca] >The PCA reduction is performed on the [3] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
# [pca] >Plot PC1 vs PC2 with loadings.

# %%
#제1주성분과 2번 컬럼이 가장 상관관계가 있으므로 2번 컬럼인 'BQ4-2'로 축소할 수 있다,
pca3=corrdata['BQ4_2']

# %%
pd.concat([pca1,pca2,pca3],axis=1)
# Out:
#       BQ1_1  BQ7B_3  BQ7B_5  BQ4_2
# 0         7     4.0     3.0      3
# 1         6     4.0     4.0      4
# 2         7     3.0     3.0      2
# 3         8     NaN     NaN      3
# 4         7     3.0     3.0      3
# ...     ...     ...     ...    ...
# 9094      7     NaN     NaN      4
# 9095      5     4.0     4.0      3
# 9096      8     NaN     NaN      5
# 9097      7     NaN     NaN      5
# 9098      6     4.0     4.0      4
#
# [9099 rows x 4 columns]

# %%
cordata=corrdata3[['AQ11_1','AQ15']]
cordata2=corrdata2[['BQ2','BQ3']]
cordata3=data1['GU']

# %%
satisdata=pd.concat([cordata3,pca1,pca2,pca3,cordata,cordata2],axis=1)

# %%
satisdata
# Out:
#        GU  BQ1_1  BQ7B_3  BQ7B_5  BQ4_2  AQ11_1  AQ15  BQ2  BQ3
# 0     110      7     4.0     3.0      3       3     1  4.0  1.0
# 1     110      6     4.0     4.0      4       4     2  4.0  3.0
# 2     110      7     3.0     3.0      2       4     3  4.0  1.0
# 3     110      8     NaN     NaN      3       3     3  6.0  2.0
# 4     110      7     3.0     3.0      3       4     3  4.0  1.0
# ...   ...    ...     ...     ...    ...     ...   ...  ...  ...
# 9094  290      7     NaN     NaN      4       4     2  2.0  1.0
# 9095  305      5     4.0     4.0      3       4     4  4.0  3.0
# 9096  410      8     NaN     NaN      5       3     4  5.0  1.0
# 9097  410      7     NaN     NaN      5       3     4  4.0  1.0
# 9098  350      6     4.0     4.0      4       3     4  3.0  2.0
#
# [9099 rows x 9 columns]

# %%
satisgroupdata=satisdata.groupby(['GU']).mean().reset_index()

# %%
satisgroupdata
# Out:
#      GU     BQ1_1    BQ7B_3    BQ7B_5     BQ4_2    AQ11_1      AQ15       BQ2  \
# 0   110  6.767241  3.417808  3.376712  3.560345  3.431034  3.060345  3.543103
# 1   140  6.817490  3.363636  3.338843  3.764259  3.577947  3.098859  3.737643
# 2   170  6.207668  3.289655  3.220690  3.597444  3.239617  3.130990  3.722045
# 3   200  6.855305  3.359477  3.496732  3.710611  3.424437  3.138264  3.881029
# 4   215  6.573290  3.318182  3.312500  3.667752  3.462541  3.136808  3.719870
# 5   230  6.707965  3.255952  3.327381  3.578171  3.315634  3.218289  3.637168
# 6   260  6.281525  3.317365  3.317365  3.563050  3.351906  3.014663  3.615836
# 7   290  6.242424  3.312236  3.291139  3.624709  3.426573  3.041958  3.713287
# 8   305  7.472973  3.474178  3.399061  3.875676  3.764865  3.370270  3.886486
# 9   320  6.402863  3.063107  3.203883  3.650307  3.423313  3.132924  3.826176
# 10  350  6.635802  3.303030  3.400000  3.663580  3.441358  3.141975  3.629630
# ...

# %%
#satisgroupdata=pd.concat([satisgroupdata,a],axis=1)

# %%
#noin=pd.read_csv("노인전처리.csv",encoding='cp949')
#a=noin['기초생활보장 수급자수']

# %%
#from scipy.stats import shapiro

# %%
#a=np.log1p(a)

# %%
satiscorr=satisgroupdata.drop('GU',axis=1).corr(method='spearman')
satiscorr
# Out:
#            BQ1_1    BQ7B_3    BQ7B_5     BQ4_2    AQ11_1      AQ15       BQ2  \
# BQ1_1   1.000000  0.660000  0.686923  0.516923  0.649231  0.519231  0.380769
# BQ7B_3  0.660000  1.000000  0.865385  0.601538  0.821538  0.430000  0.500769
# BQ7B_5  0.686923  0.865385  1.000000  0.595385  0.676154  0.533846  0.443846
# BQ4_2   0.516923  0.601538  0.595385  1.000000  0.793846  0.484615  0.615385
# AQ11_1  0.649231  0.821538  0.676154  0.793846  1.000000  0.436923  0.663846
# AQ15    0.519231  0.430000  0.533846  0.484615  0.436923  1.000000  0.472308
# BQ2     0.380769  0.500769  0.443846  0.615385  0.663846  0.472308  1.000000
# BQ3    -0.546923 -0.517692 -0.374615 -0.395385 -0.416154 -0.368462 -0.425385
#
#              BQ3
# BQ1_1  -0.546923
# BQ7B_3 -0.517692
# BQ7B_5 -0.374615
# BQ4_2  -0.395385
# AQ11_1 -0.416154
# AQ15   -0.368462
# BQ2    -0.425385
# BQ3     1.000000

# %%
font_location = 'C:/Windows/Fonts/MALGUNSL.TTF'
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
corhmap(satiscorr)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7864\1823761758.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(cor, dtype=np.bool)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#total=-0.1-0.028+0.073+0.067-0.027+0.14-0.17+0.14

# %%
#BQ1_1=-0.1/total
#BQ7B_3 = -0.028/total
#BQ7B_5 = 0.073/total
#BQ4_2 = 0.067/total
#AQ11_1 = -0.027/total
#AQ15 = 0.14/total
#BQ2 = -0.17/total
#BQ3 = 0.14/total

# %%
#print([BQ1_1,BQ7B_3,BQ7B_5,BQ4_2,AQ11_1,AQ15,BQ2,BQ3])
# Out:
# [-1.0526315789473684, -0.2947368421052632, 0.7684210526315789, 0.7052631578947369, -0.28421052631578947, 1.473684210526316, -1.7894736842105263, 1.473684210526316]

# %%
#기초생활수급자수= -1.05BQ1_1 - 0.29BQ7B_3 + 0.77BQ7B_5 + 0.71BQ4_2 - 0.28AQ11_1 + 1.47AQ15 - 1.79BQ2 + 1.47BQ3

# %%
#from statsmodels.formula.api import ols

# %%
#satisgroupdata=satisgroupdata.rename(columns={'기초생활보장 수급자수':'기초생활보장수급자수'})

# %%
from statsmodels.formula.api import ols
model=ols('BQ1_1~BQ7B_3+BQ7B_5+BQ4_2+AQ11_1+AQ15+BQ2+BQ3',satisgroupdata)
res=model.fit()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')
# Out:
#        컬럼       VIF
# 0  BQ7B_3  5.088320
# 1  BQ7B_5  4.161858
# 2   BQ4_2  4.273822
# 3  AQ11_1  5.494028
# 4    AQ15  1.847286
# 5     BQ2  1.939306
# 6     BQ3  1.678778

# %%
model=ols('BQ1_1~BQ7B_3+BQ7B_5+BQ4_2+AQ11_1+AQ15+BQ2+BQ3',satisgroupdata).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  BQ1_1   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.780
# Method:                 Least Squares   F-statistic:                     13.13
# Date:                Tue, 09 Aug 2022   Prob (F-statistic):           9.62e-06
# Time:                        01:03:28   Log-Likelihood:                 17.446
# No. Observations:                  25   AIC:                            -18.89
# Df Residuals:                      17   BIC:                            -9.140
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9687      1.655      1.793      0.091      -0.524       6.461
# ...

# %%
#선형성
font_location = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
fitted=model.predict()
residual = satisgroupdata['BQ1_1']-fitted

sns.regplot(fitted, residual, lowess=True, line_kws={'color':'red'})
plt.plot([fitted.min(),fitted.max()], [0,0], '--', color='grey')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#정규성
import scipy.stats
sr = scipy.stats.zscore(residual)
(x, y), _ = scipy.stats.probplot(sr)
sns.scatterplot(x,y)
plt.plot([-3,3],[-3,3],'--',color='grey')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#등분산성
import numpy as np
sns.regplot(fitted, np.sqrt(np.abs(sr)),lowess=True, line_kws={'color':'red'})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='BQ1_1'>

# %% [markdown]
# ### 만족도 가중치
# 만족도 = 2.969 + 1.499BQ7B_5 - 1.334BQ4_2 + 1.902AQ11_1 + 1.244AQ15 - 0.706BQ3
#
# 회귀분석 가중치 : 해당 변수의 회귀계수 /모든 회귀계수 beta의 합

# %%
beta=2.969+1.499-1.334+1.902+1.244-0.706
BQ7B_5 = 1.499/beta
BQ4_2 = -1.334/beta
AQ11_1 = 1.902/beta
AQ15 = 1.244/beta
BQ3 = -0.706/beta
[BQ7B_5,BQ4_2,AQ11_1,AQ15,BQ3]
# Out:
# [0.2689271618227485,
#  -0.23932543954072483,
#  0.341227125941873,
#  0.22317904556871188,
#  -0.126659490491568]

# %% [markdown]
# 만족도 지표 = 0.269BQ7B_5 - 0.239BQ4_2 + 0.341AQ11_1 + 0.223AQ15 - 0.127BQ3

# %%
satisgroupdata['satisfy']=0.269*satisgroupdata['BQ7B_5'] - 0.239*satisgroupdata['BQ4_2'] + 0.341*satisgroupdata['AQ11_1'] + 0.223*satisgroupdata['AQ15'] - 0.127*satisgroupdata['BQ3']

# %%
def GU(x):
    div=''
    if x==110:
        div='종로구'
    elif x==140:
        div='중구'
    elif x==170:
        div='용산구'
    elif x==200:
        div='성동구'
    elif x==215:
        div='광진구'
    elif x==230:
        div='동대문구'
    elif x==260:
        div='중랑구'
    elif x==290:
        div='성북구'
    elif x==305:
        div='강북구'
    elif x==320:
        div='도봉구'
    elif x==350:
        div='노원구'
    elif x==380:
        div='은평구'
    elif x==410:
        div='서대문구'
    elif x==440:
        div='마포구'
    elif x==470:
        div='양천구'
    elif x==500:
        div='강서구'
    elif x==530:
        div='구로구'
    elif x==545:
        div='금천구'
    elif x==560:
        div='영등포구'
    elif x==590:
        div='동작구'
    elif x==620:
        div='관악구'
    elif x==650:
        div='서초구'
    elif x==680:
        div='강남구'
    elif x==710:
        div='송파구'
    else:
        div='강동구'
    return div
satisgroupdata['GU']=satisgroupdata['GU'].apply(lambda x: GU(x))

# %%
save=satisgroupdata[['GU','satisfy']].sort_values(by='GU')
save
# Out:
#       GU   satisfy
# 22   강남구  1.683953
# 24   강동구  1.481157
# 8    강북구  1.785926
# 15   강서구  1.540820
# 20   관악구  1.626316
# 4    광진구  1.600577
# 16   구로구  1.470217
# 17   금천구  1.523511
# 10   노원구  1.606251
# 9    도봉구  1.553626
# 5   동대문구  1.580620
# 19   동작구  1.498208
# 13   마포구  1.586085
# 12  서대문구  1.656217
# 21   서초구  1.630690
# 3    성동구  1.648158
# 7    성북구  1.577193
# 23   송파구  1.634723
# 14   양천구  1.462379
# 18  영등포구  1.486296
# 2    용산구  1.528717
# 11   은평구  1.541263
# 0    종로구  1.630672
# 1     중구  1.619400
# 6    중랑구  1.542483

# %%
save.to_csv("구역별 만족도 지표.csv",encoding='cp949',index=False)
